# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 18688276
paper_name = 'ericson_nislow_2008'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/pgen.1000151.s003.xlsx', sheet_name='Sheet1', skiprows=2)

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 5226 x 95

# %%
original_data.head()
# Out:
#        ORF  Gene  6-nitroquipazine maleate  Fluvoxamine maleate  Zardaverine  \
# 0  YAL001C  TFC3                 -0.808898            -1.325010    -0.670831
# 1  YAL002W  VPS8                 -1.097630            -0.770822    -0.991552
# 2  YAL003W  EFB1                 -0.483805            -0.335716    -0.450622
# 3  YAL005C  SSA1                 -0.047399            -0.094895     0.004581
# 4  YAL007C  ERP2                  0.115854            -0.014314    -0.075712
#
#    Imetit dihydrobromide  Iodophenpropit dihydrobromide  Salmeterol  \
# 0              -0.325576                      -0.252302   -0.172921
# 1              -1.197220                      -0.793416   -0.761811
# 2              -0.182541                      -0.434479   -0.781484
# 3              -0.028918                      -0.035101   -0.108385
# 4               0.204233                       0.017717    0.219656
#
#    SR 59230A hydrochloride  LY 367385  ...  Clomipramine hydrochloride.1  \
# 0                 0.010748  -0.580010  ...                     -0.759544
# 1                -0.301568  -0.779557  ...                      0.489359
# 2                -0.781484  -0.536665  ...                      0.606146
# 3                -0.159151  -0.112678  ...                      0.007500
# 4                -0.094251   0.104052  ...                     -0.358478
#
#    SKF 83822 hydrobromide  SKF 83822 hydrobromide.1  \
# 0               -0.098509                 -0.396676
# 1                0.066836                  0.101663
# 2                0.582290                  0.838908
# 3                0.081721                  0.089917
# 4               -0.077984                 -0.193587
#
#                                          Description  Feature_qualifier  \
# 0  Largest of six subunits of the RNA polymerase ...           Verified
# 1  Membrane-associated hydrophilic protein that i...           Verified
# 2  Translation elongation factor 1 beta; stimulat...           Verified
# 3  ATPase involved in protein folding and nuclear...           Verified
# 4  Protein that forms a heterotrimeric complex wi...           Verified
#
#                                           GO_process  \
# 0  transcription initiation from RNA polymerase I...
# 1                 late endosome to vacuole transport
# 2                           translational elongation
# 3                                       translation*
# 4             ER to Golgi vesicle-mediated transport
#
#                                         GO_function  \
# 0  RNA polymerase III transcription factor activity
# 1                        molecular function unknown
# 2            translation elongation factor activity
# 3                                  ATPase activity*
# 4                        molecular function unknown
#
#                     GO_component  Essential_gene  Zygosity
# 0                 mitochondrion*             yes       het
# 1              membrane fraction              no       hom
# 2                      ribosome*             yes       het
# 3                     cytoplasm*              no       hom
# 4  ER to Golgi transport vesicle              no       hom
#
# [5 rows x 95 columns]

# %%
original_data['orf'] = original_data['ORF'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [ORF, Gene, 6-nitroquipazine maleate, Fluvoxamine maleate, Zardaverine, Imetit dihydrobromide, Iodophenpropit dihydrobromide, Salmeterol, SR 59230A hydrochloride, LY 367385, MPEP hydrochloride, CGP 78608 hydrochloride, (S)-MCPG, 7-chlorokynurenic acid, GBR 13069 dihydrochloride, GBR 12909 dihydrochloride, GBR 12783 dihydrochloride, GBR 12935 dihydrochloride, (RS)-(+/-)-Sulpiride, 3'-Fluorobenzylspiperone maleate, A 77636 hydrochloride, 3a-Bis-(4-fluorophenyl) methoxytropane hydrochloride, Haloperidol hydrochloride, Bromocriptine mesylate, AMI-193, (+)-AJ 76 hydrochloride, BTCP, 7-Hydroxy-PIPAT maleate, (S)-(-)-sulpiride, Metergoline, Parthenolide, 5-Nonyloxytryptamine oxalate, Cyproheptadine hydrochloride, GR 127935 hydrochloride, NAN 190 hydrobromide, CGS 12066B dimaleate, Paroxetine maleate, WAY 629, Altanserin hydrochloride, Sertraline hydrochloride, Ritanserin, Carmoxirole hydrochloride, SCH 39166 hydrobromide, L-741,741 hydrochloride, CY 208-243, L741,742 hydrochloride, Pimozide, PD 168077 maleate, GR 103691, Nafadotride, SKF 81297 hydrobromide, Roxindole hydrochloride, SKF 83566 hydrobromide, Fenoldopam hydrochloride, (S)-(-)-5-fluorowillardiine, Clobenpropit dihydrobromide, SKF 77434 hydrobromide, Nemonapride, Amisulpride, Tetrabenazine, 3a-[(4-Chlorophenyl)phenylmethoxy] tropane hydrochloride, N-Desmethylclozapine, Fluoxetine hydrochloride, Tropanyl 3,5-dimethylbenzoate, RS 39604 hydrochloride, BRL 15572 hydrochloride, SB 228357, SB 206553 hydrochloride, N-Methylquipazine dimaleate, MDL 11,939, SB 216641 hydrochloride, 4F 4PP, S 14506 hydrochloride, SKF 83959 hydrobromide, Methiothepin maleate, Indatraline hydrochloride, MDL 72222, WB 4101 hydrochloride, Clozapine, Clozapine.1, 2-Chloro-11-(4-methylpiperazino)dibenz[b,f]oxepin maleate, 2-Chloro-11-(4-methylpiperazino)dibenz[b,f]oxepin maleate.1, SB 224289 hydrochloride, SB 224289 hydrochloride.1, Clomipramine hydrochloride, Clomipramine hydrochloride.1, SKF 83822 hydrobromide, SKF 83822 hydrobromide.1, Description, Feature_qualifier, GO_process, GO_function, GO_component, Essential_gene, Zygosity, orf]
# Index: []
#
# [0 rows x 96 columns]

# %%
original_data.set_index('orf', inplace=True)

# %%
data_cols = original_data.columns[np.arange(2,88)]

# %%
original_data1 = original_data.loc[original_data['Zygosity']=='hom',data_cols].copy()
original_data2 = original_data.loc[original_data['Zygosity']=='het',data_cols].copy()

# %%
original_data1 = original_data1.apply(pd.to_numeric, axis=1, errors='coerce')
original_data2 = original_data2.apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data1 = original_data1.groupby(original_data1.index).mean()
original_data2 = original_data2.groupby(original_data2.index).mean()

# %%
original_data1.shape
# Out:
# (4201, 86)

# %%
original_data2.shape
# Out:
# (1000, 86)

# %% [markdown]
# # Load dataset info

# %%
original_data1.columns = [c.split('.')[0] for c in original_data1.columns.values]
original_data2.columns = [c.split('.')[0] for c in original_data2.columns.values]

# %%
df = pd.read_excel('extras/drug_dataset.xlsx', sheet_name='Sheet1')
df.set_index('Unnamed: 0', inplace=True)

# %%
df.drop_duplicates(subset=['Hom dataset','Het dataset'], inplace=True)
df.shape
# Out:
# (81, 4)

# %%
hom_dataset_id = [df.loc[c,'Hom dataset'] for c in original_data1.columns.values]
het_dataset_id = [df.loc[c,'Het dataset'] for c in original_data1.columns.values]

# %%
original_data1.columns = hom_dataset_id
original_data2.columns = het_dataset_id

# %%
original_data1 = original_data1.T
original_data1 = original_data1.groupby(original_data1.index).mean()
original_data1 = original_data1.T
original_data1.shape
# Out:
# (4201, 81)

# %%
original_data2 = original_data2.T
original_data2 = original_data2.groupby(original_data2.index).mean()
original_data2 = original_data2.T
original_data2.shape
# Out:
# (1000, 81)

# %%
original_data = original_data1.join(original_data2, how='outer')

# %%
original_data.head()
# Out:
#              509       5009      5010      5011      5012      5013      5014  \
# orf
# YAL001C       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YAL002W  1.084844  0.770241  0.714035  0.307677  0.600430 -0.728671  1.333645
# YAL003W       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YAL004W  0.585719  0.861604  0.545551 -0.031649  0.128335 -0.071324  0.668568
# YAL005C  0.052817  0.000286  0.035713  0.011217  0.106191 -0.035101 -0.021304
#
#              5015      5016      5017  ...      5160      5161      5162  \
# orf                                    ...
# YAL001C       NaN       NaN       NaN  ...  0.382196  0.540964 -0.247592
# YAL002W  0.977858  1.314040  1.893110  ...       NaN       NaN       NaN
# YAL003W       NaN       NaN       NaN  ...  0.305760 -0.017437  0.710599
# YAL004W  0.277145  0.034361  0.899422  ...       NaN       NaN       NaN
# YAL005C  0.081318 -0.012155  0.016566  ...       NaN       NaN       NaN
#
#              5163      5164      5165      5166     5167      5168      5169
# orf
# YAL001C  0.270842  0.010748  0.886951  0.025027 -1.95364 -0.566970 -0.670831
# YAL002W       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# YAL003W  0.589144 -0.781484  0.096067 -1.632280 -2.38105  0.223168 -0.450622
# YAL004W       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# YAL005C       NaN       NaN       NaN       NaN      NaN       NaN       NaN
#
# [5 rows x 162 columns]

# %%
# Taking the opposite because the original data is log2(ctrl/treatment)
original_data = -original_data

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = original_data.columns.values
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id      509       5009      5010      5011      5012      5013  \
# data_type      value     value     value     value     value     value
# orf
# YAL001C          NaN       NaN       NaN       NaN       NaN       NaN
# YAL002W    -1.084844 -0.770241 -0.714035 -0.307677 -0.600430  0.728671
# YAL003W          NaN       NaN       NaN       NaN       NaN       NaN
# YAL004W    -0.585719 -0.861604 -0.545551  0.031649 -0.128335  0.071324
# YAL005C    -0.052817 -0.000286 -0.035713 -0.011217 -0.106191  0.035101
#
# dataset_id      5014      5015      5016      5017  ...      5160      5161  \
# data_type      value     value     value     value  ...     value     value
# orf                                                 ...
# YAL001C          NaN       NaN       NaN       NaN  ... -0.382196 -0.540964
# YAL002W    -1.333645 -0.977858 -1.314040 -1.893110  ...       NaN       NaN
# YAL003W          NaN       NaN       NaN       NaN  ... -0.305760  0.017437
# YAL004W    -0.668568 -0.277145 -0.034361 -0.899422  ...       NaN       NaN
# YAL005C     0.021304 -0.081318  0.012155 -0.016566  ...       NaN       NaN
#
# dataset_id      5162      5163      5164      5165      5166     5167  \
# data_type      value     value     value     value     value    value
# orf
# YAL001C     0.247592 -0.270842 -0.010748 -0.886951 -0.025027  1.95364
# YAL002W          NaN       NaN       NaN       NaN       NaN      NaN
# YAL003W    -0.710599 -0.589144  0.781484 -0.096067  1.632280  2.38105
# YAL004W          NaN       NaN       NaN       NaN       NaN      NaN
# YAL005C          NaN       NaN       NaN       NaN       NaN      NaN
#
# dataset_id      5168      5169
# data_type      value     value
# orf
# YAL001C     0.566970  0.670831
# YAL002W          NaN       NaN
# YAL003W    -0.223168  0.450622
# YAL004W          NaN       NaN
# YAL005C          NaN       NaN
#
# [5 rows x 162 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 3

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id           509       5009      5010      5011      5012      5013  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C       NaN       NaN       NaN       NaN       NaN       NaN
# 2       YAL002W -1.084844 -0.770241 -0.714035 -0.307677 -0.600430  0.728671
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W -0.585719 -0.861604 -0.545551  0.031649 -0.128335  0.071324
# 4       YAL005C -0.052817 -0.000286 -0.035713 -0.011217 -0.106191  0.035101
#
# dataset_id           5014      5015      5016      5017  ...      5160  \
# data_type           value     value     value     value  ...     value
# gene_id orf                                              ...
# 1       YAL001C       NaN       NaN       NaN       NaN  ... -0.382196
# 2       YAL002W -1.333645 -0.977858 -1.314040 -1.893110  ...       NaN
# 3       YAL003W       NaN       NaN       NaN       NaN  ... -0.305760
# 1863    YAL004W -0.668568 -0.277145 -0.034361 -0.899422  ...       NaN
# 4       YAL005C  0.021304 -0.081318  0.012155 -0.016566  ...       NaN
#
# dataset_id           5161      5162      5163      5164      5165      5166  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C -0.540964  0.247592 -0.270842 -0.010748 -0.886951 -0.025027
# 2       YAL002W       NaN       NaN       NaN       NaN       NaN       NaN
# 3       YAL003W  0.017437 -0.710599 -0.589144  0.781484 -0.096067  1.632280
# 1863    YAL004W       NaN       NaN       NaN       NaN       NaN       NaN
# 4       YAL005C       NaN       NaN       NaN       NaN       NaN       NaN
#
# dataset_id          5167      5168      5169
# data_type          value     value     value
# gene_id orf
# 1       YAL001C  1.95364  0.566970  0.670831
# 2       YAL002W      NaN       NaN       NaN
# 3       YAL003W  2.38105 -0.223168  0.450622
# 1863    YAL004W      NaN       NaN       NaN
# 4       YAL005C      NaN       NaN       NaN
#
# [5 rows x 162 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id           509       5009      5010      5011      5012      5013  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C       NaN       NaN       NaN       NaN       NaN       NaN
# 2       YAL002W -1.084844 -0.770241 -0.714035 -0.307677 -0.600430  0.728671
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W -0.585719 -0.861604 -0.545551  0.031649 -0.128335  0.071324
# 4       YAL005C -0.052817 -0.000286 -0.035713 -0.011217 -0.106191  0.035101
#
# dataset_id           5014      5015      5016      5017  ...      5160  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 1       YAL001C       NaN       NaN       NaN       NaN  ... -1.050786
# 2       YAL002W -1.333645 -0.977858 -1.314040 -1.893110  ...       NaN
# 3       YAL003W       NaN       NaN       NaN       NaN  ... -0.813571
# 1863    YAL004W -0.668568 -0.277145 -0.034361 -0.899422  ...       NaN
# 4       YAL005C  0.021304 -0.081318  0.012155 -0.016566  ...       NaN
#
# dataset_id           5161      5162      5163      5164      5165      5166  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 1       YAL001C -1.516537  0.658254 -0.471059  0.004237 -2.487809  0.032597
# 2       YAL002W       NaN       NaN       NaN       NaN       NaN       NaN
# 3       YAL003W  0.149839 -1.381854 -1.209329  0.954479 -0.350222  2.461696
# 1863    YAL004W       NaN       NaN       NaN       NaN       NaN       NaN
# 4       YAL005C       NaN       NaN       NaN       NaN       NaN       NaN
#
# dataset_id           5167      5168      5169
# data_type          valuez    valuez    valuez
# gene_id orf
# 1       YAL001C  1.232247  1.775887  1.244189
# 2       YAL002W       NaN       NaN       NaN
# 3       YAL003W  1.476978 -0.650938  0.800455
# 1863    YAL004W       NaN       NaN       NaN
# 4       YAL005C       NaN       NaN       NaN
#
# [5 rows x 324 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 18688276...
#   0%|          | 0/162 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 162/162 [20:30<00:00,  7.59s/it]
# Updating the data_modified_on field...
