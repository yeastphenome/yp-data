# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 34663920
paper_name = 'vieitez_beltrao_2021'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/41587_2021_1051_MOESM5_ESM.xlsx', sheet_name='Table S3 – S_Scores of chemical')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 540817 x 8

# %%
original_data.head()
# Out:
#                                Strain Condition     Score Plate  PBY ID  \
# 0  PBY365__Y8205__STE20-T575A__040102    48H-20 -0.984050    P4  PBY365
# 1   PBY701__Y8205__BIM1-S172A__040103    48H-20 -0.908803    P4  PBY701
# 2  PBY445__Y8205__PHO23-S264A__040104    48H-20 -0.976347    P4  PBY445
# 3  PBY879__Y8205__RPC53-S234A__040106    48H-20 -0.656309    P4  PBY879
# 4    PBY578__Y8205__VMA2-T83A__040108    48H-20 -0.476490    P4  PBY578
#
#      Mutant_type Systematic_name    qvalue
# 0  phosphomutant         YHL007C  0.814834
# 1  phosphomutant         YER016W  0.833546
# 2  phosphomutant         YNL097C  0.814834
# 3  phosphomutant         YDL150W  0.946614
# 4  phosphomutant         YBR127C  0.984735

# %%
original_data = original_data.loc[original_data['Mutant_type']=='KO']

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 492501 x 8

# %%
t = pd.pivot_table(original_data, index='Systematic_name', columns='Condition', values='Score')

# %%
original_data = t.copy().reset_index()

# %%
original_data['orf'] = original_data['Systematic_name'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Condition   Systematic_name    48H-20   48H-24D    48H-37    48H-39    48H-42  \
# index_input
# 3193               YLR287-A -2.270455  0.309799 -0.138605 -0.850785 -0.859868
#
# Condition     48H-5FU   48H-6AU  48H-6AU39  48H-AA  ...  72H-ETOH39  72H-GLYC  \
# index_input                                         ...
# 3193         1.451824  2.819405  -0.937676     NaN  ...   -1.039763  1.220097
#
# Condition     72H-MAL  72H-NACL439  72H-NACL6  72H-NACL639  72H-PARA  \
# index_input
# 3193         1.051405    -0.347562   0.395891      0.05002  1.942319
#
# Condition    72H-RAPA39  72H-XLGLU       orf
# index_input
# 3193           0.238927    1.64344  YLR287-A
#
# [1 rows x 104 columns]

# %%
original_data.loc[original_data['orf']=='YLR287-A','orf'] = 'YLR287C-A'

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4859, 102)

# %%
original_data.head()
# Out:
# Condition    48H-20   48H-24D    48H-37    48H-39    48H-42   48H-5FU  \
# orf
# YAL002W    0.896462 -7.404396 -1.306682 -2.728890 -0.550666 -3.135267
# YAL004W   -0.416342  0.035906  1.474327  0.237645 -2.370390 -1.353389
# YAL005C   -0.685679 -1.134804 -0.151774 -1.397882 -0.621069  1.404865
# YAL007C   -0.105546  0.075773  1.284279  0.780764 -0.742151 -0.567071
# YAL008W   -0.271289  1.448353  0.097858  0.984250  0.564519 -0.352081
#
# Condition   48H-6AU  48H-6AU39    48H-AA  48H-AMPHO  ...     72H-CU  \
# orf                                                  ...
# YAL002W    1.623408  -4.119181 -3.720051   0.280291  ... -11.646350
# YAL004W    0.682456   0.518715  1.832033   0.822571  ...  -1.942069
# YAL005C    1.067774  -2.056695 -0.318258   0.085912  ...   0.049775
# YAL007C   -1.481874  -0.206407  0.237673   0.208001  ...  -2.292795
# YAL008W   -0.139841   0.364442  0.074970   1.089034  ...   0.931726
#
# Condition  72H-ETOH39  72H-GLYC   72H-MAL  72H-NACL439  72H-NACL6  \
# orf
# YAL002W     -0.423683 -0.550796  1.081764    -0.805571   1.626975
# YAL004W     -2.335991 -1.258885  0.933605     0.390778  -1.151692
# YAL005C     -1.989421 -0.907996  1.803635    -0.697065  -0.966572
# YAL007C     -0.341254 -2.122047  1.120219     0.508619   0.966392
# YAL008W      0.883637 -2.466913 -1.427905     0.863191  -0.328052
#
# Condition  72H-NACL639  72H-PARA  72H-RAPA39  72H-XLGLU
# orf
# YAL002W      -0.763178  2.139201   -2.406891   0.517362
# YAL004W       0.006402 -1.946547   -0.580464   1.591234
# YAL005C      -0.096049 -0.865883   -0.504526   0.342426
# YAL007C      -0.012325  0.137126    0.428717   0.124757
# YAL008W      -0.769127  0.234910    1.224057  -0.873417
#
# [5 rows x 102 columns]

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
cond2dt = pd.read_csv('raw_data/condition_2_dataset.txt', sep='\t')
print(cond2dt.shape)
# Out:
# (102, 3)

# %%
cond2dt['condition_id_fix'] = cond2dt['condition_id_fix'].str.upper()

# %%
cond2dt.set_index('condition_id_fix', inplace=True)

# %%
cond2dt = cond2dt.reindex(index=data.columns)

# %%
cond2dt.loc[cond2dt['dataset_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, dataset_id]
# Index: []

# %%
cond2dt.head()
# Out:
#            Unnamed: 0  dataset_id
# Condition
# 48H-20              1       22111
# 48H-24D             0       22094
# 48H-37              2       22112
# 48H-39              3       22113
# 48H-42              5       22115

# %%
dataset_ids = cond2dt['dataset_id'].values
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id     22111     22094     22112     22113     22115     22157  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W     0.896462 -7.404396 -1.306682 -2.728890 -0.550666 -3.135267
# YAL004W    -0.416342  0.035906  1.474327  0.237645 -2.370390 -1.353389
# YAL005C    -0.685679 -1.134804 -0.151774 -1.397882 -0.621069  1.404865
# YAL007C    -0.105546  0.075773  1.284279  0.780764 -0.742151 -0.567071
# YAL008W    -0.271289  1.448353  0.097858  0.984250  0.564519 -0.352081
#
# dataset_id     22116     22117     22119     22121  ...      22143     22150  \
# data_type      value     value     value     value  ...      value     value
# orf                                                 ...
# YAL002W     1.623408 -4.119181 -3.720051  0.280291  ... -11.646350 -0.423683
# YAL004W     0.682456  0.518715  1.832033  0.822571  ...  -1.942069 -2.335991
# YAL005C     1.067774 -2.056695 -0.318258  0.085912  ...   0.049775 -1.989421
# YAL007C    -1.481874 -0.206407  0.237673  0.208001  ...  -2.292795 -0.341254
# YAL008W    -0.139841  0.364442  0.074970  1.089034  ...   0.931726  0.883637
#
# dataset_id     22163     22173     22201     22203     22179     22186  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W    -0.550796  1.081764 -0.805571  1.626975 -0.763178  2.139201
# YAL004W    -1.258885  0.933605  0.390778 -1.151692  0.006402 -1.946547
# YAL005C    -0.907996  1.803635 -0.697065 -0.966572 -0.096049 -0.865883
# YAL007C    -2.122047  1.120219  0.508619  0.966392 -0.012325  0.137126
# YAL008W    -2.466913 -1.427905  0.863191 -0.328052 -0.769127  0.234910
#
# dataset_id     22195     22159
# data_type      value     value
# orf
# YAL002W    -2.406891  0.517362
# YAL004W    -0.580464  1.591234
# YAL005C    -0.504526  0.342426
# YAL007C     0.428717  0.124757
# YAL008W     1.224057 -0.873417
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 23

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id          22111     22094     22112     22113     22115     22157  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W  0.896462 -7.404396 -1.306682 -2.728890 -0.550666 -3.135267
# 1863    YAL004W -0.416342  0.035906  1.474327  0.237645 -2.370390 -1.353389
# 4       YAL005C -0.685679 -1.134804 -0.151774 -1.397882 -0.621069  1.404865
# 5       YAL007C -0.105546  0.075773  1.284279  0.780764 -0.742151 -0.567071
# 6       YAL008W -0.271289  1.448353  0.097858  0.984250  0.564519 -0.352081
#
# dataset_id          22116     22117     22119     22121  ...      22143  \
# data_type           value     value     value     value  ...      value
# gene_id orf                                              ...
# 2       YAL002W  1.623408 -4.119181 -3.720051  0.280291  ... -11.646350
# 1863    YAL004W  0.682456  0.518715  1.832033  0.822571  ...  -1.942069
# 4       YAL005C  1.067774 -2.056695 -0.318258  0.085912  ...   0.049775
# 5       YAL007C -1.481874 -0.206407  0.237673  0.208001  ...  -2.292795
# 6       YAL008W -0.139841  0.364442  0.074970  1.089034  ...   0.931726
#
# dataset_id          22150     22163     22173     22201     22203     22179  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W -0.423683 -0.550796  1.081764 -0.805571  1.626975 -0.763178
# 1863    YAL004W -2.335991 -1.258885  0.933605  0.390778 -1.151692  0.006402
# 4       YAL005C -1.989421 -0.907996  1.803635 -0.697065 -0.966572 -0.096049
# 5       YAL007C -0.341254 -2.122047  1.120219  0.508619  0.966392 -0.012325
# 6       YAL008W  0.883637 -2.466913 -1.427905  0.863191 -0.328052 -0.769127
#
# dataset_id          22186     22195     22159
# data_type           value     value     value
# gene_id orf
# 2       YAL002W  2.139201 -2.406891  0.517362
# 1863    YAL004W -1.946547 -0.580464  1.591234
# 4       YAL005C -0.865883 -0.504526  0.342426
# 5       YAL007C  0.137126  0.428717  0.124757
# 6       YAL008W  0.234910  1.224057 -0.873417
#
# [5 rows x 102 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id          22111     22094     22112     22113     22115     22157  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W  0.896462 -7.404396 -1.306682 -2.728890 -0.550666 -3.135267
# 1863    YAL004W -0.416342  0.035906  1.474327  0.237645 -2.370390 -1.353389
# 4       YAL005C -0.685679 -1.134804 -0.151774 -1.397882 -0.621069  1.404865
# 5       YAL007C -0.105546  0.075773  1.284279  0.780764 -0.742151 -0.567071
# 6       YAL008W -0.271289  1.448353  0.097858  0.984250  0.564519 -0.352081
#
# dataset_id          22116     22117     22119     22121  ...     22143  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 2       YAL002W  1.623408 -4.119181 -3.720051  0.280291  ... -3.100076
# 1863    YAL004W  0.682456  0.518715  1.832033  0.822571  ... -0.763498
# 4       YAL005C  1.067774 -2.056695 -0.318258  0.085912  ... -0.283905
# 5       YAL007C -1.481874 -0.206407  0.237673  0.208001  ... -0.847945
# 6       YAL008W -0.139841  0.364442  0.074970  1.089034  ... -0.071551
#
# dataset_id          22150     22163     22173     22201     22203     22179  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W -0.258360 -0.145236  0.202665 -0.846925  1.395911 -0.775045
# 1863    YAL004W -1.705237 -0.308759  0.159415  0.082678 -1.068992 -0.111843
# 4       YAL005C -1.443018 -0.227726  0.413387 -0.762612 -0.904775 -0.200132
# 5       YAL007C -0.195994 -0.508094  0.213890  0.174245  0.809921 -0.127981
# 6       YAL008W  0.730775 -0.587736 -0.529937  0.449759 -0.338356 -0.780171
#
# dataset_id          22186     22195     22159
# data_type          valuez    valuez    valuez
# gene_id orf
# 2       YAL002W  1.423963 -1.621720  0.065825
# 1863    YAL004W -1.187080 -0.278430  0.515625
# 4       YAL005C -0.496470 -0.222580 -0.007448
# 5       YAL007C  0.144514  0.463797 -0.098621
# 6       YAL008W  0.207004  1.048749 -0.516714
#
# [5 rows x 204 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
#   0%|          | 0/102 [00:00<?, ?it/s]
# Deleting all datasets for PMID 34663920...
# Inserting the new data...
# 100%|██████████| 102/102 [11:09<00:00,  6.56s/it]
# Updating the data_modified_on field...
