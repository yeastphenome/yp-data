# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 12496357
paper_name = 'begley_samson_2002'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/ORIG130404_Begley2001raw.xlsx', sheet_name='Sheet1')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 9647 x 238

# %%
original_data.head()
# Out:
#                        position on plate  \
# 0                                    NaN
# 1      Data in red indicates that there
# 2  was no ORF or control at that postion
# 3        on the plate, or that what was
# 4       spotted in that position did not
#
#   plate number (Research Genetics  designations) Gene Name  ORF Treatment  \
# 0                                            NaN       NaN  NaN       NaN
# 1                                            NaN       NaN  NaN       NaN
# 2                                            NaN       NaN  NaN       NaN
# 3                                            NaN       NaN  NaN       NaN
# 4                                            NaN       NaN  NaN       NaN
#
#                              exp 1 highest sensitive exp 2 highest sensitive  \
# 0                                                NaN                     NaN
# 1                                   O = no phenotype                     NaN
# 2                         1 = sensitive at that dose                     NaN
# 3            2 = failed quality control at that dose                     NaN
# 4  3, 5 = manually failed quality control at that...                     NaN
#
#   exp 3 highest sensitive exp 1 lowest sensitive exp 2 lowest sensitive  ...  \
# 0                     NaN                    NaN                    NaN  ...
# 1                     NaN                    NaN                    NaN  ...
# 2                     NaN                    NaN                    NaN  ...
# 3                     NaN                    NaN                    NaN  ...
# 4                     NaN                    NaN                    NaN  ...
#
#                                   Empty Unnamed: 229 exp1 sensitive  \
# 0                                   NaN          NaN            NaN
# 1    A "1" here indicates that this is           NaN            NaN
# 2  an empty well, with no yeast spotted          NaN            NaN
# 3                                   NaN          NaN            NaN
# 4                                   NaN          NaN            NaN
#
#   exp2 sensitive exp3 sensitive total sensitive exp1 resistant  \
# 0            NaN            NaN             NaN            NaN
# 1            NaN            NaN             NaN            NaN
# 2            NaN            NaN             NaN            NaN
# 3            NaN            NaN             NaN            NaN
# 4            NaN            NaN             NaN            NaN
#
#    exp2 resistant exp3 resistant total resistant
# 0             NaN            NaN             NaN
# 1             NaN            NaN             NaN
# 2             NaN            NaN             NaN
# 3             NaN            NaN             NaN
# 4             NaN            NaN             NaN
#
# [5 rows x 238 columns]

# %%
original_data['orf'] = original_data['ORF'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
typo_fixes = {'YKLO72W':'YKL072W','YOLO57W':'YOL057W','YOLO62C':'YOL062C'}
original_data['orf'] = original_data['orf'].apply(lambda x: typo_fixes[x] if x in typo_fixes.keys() else x)

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
#                                  position on plate  \
# index_input
# 0                                              NaN
# 1                Data in red indicates that there
# 2            was no ORF or control at that postion
# 3                  on the plate, or that what was
# 4                 spotted in that position did not
# ...                                            ...
# 9642                                            8H
# 9643                                            9H
# 9644                                           10H
# 9645                                           11H
# 9646                                           12H
#
#             plate number (Research Genetics  designations) Gene Name  ORF  \
# index_input
# 0                                                      NaN       NaN  NaN
# 1                                                      NaN       NaN  NaN
# 2                                                      NaN       NaN  NaN
# 3                                                      NaN       NaN  NaN
# 4                                                      NaN       NaN  NaN
# ...                                                    ...       ...  ...
# 9642                                                   8_3       NaN  NaN
# 9643                                                   8_3       NaN  NaN
# 9644                                                   8_3       NaN  NaN
# 9645                                                   8_3       NaN  NaN
# 9646                                                   8_3       NaN  NaN
#
#             Treatment                            exp 1 highest sensitive  \
# index_input
# 0                 NaN                                                NaN
# 1                 NaN                                   O = no phenotype
# 2                 NaN                         1 = sensitive at that dose
# 3                 NaN            2 = failed quality control at that dose
# 4                 NaN  3, 5 = manually failed quality control at that...
# ...               ...                                                ...
# 9642          UV data                                               OOOO
# 9643          UV data                                               OOOO
# 9644          UV data                                               O111
# 9645          UV data                                               OO11
# 9646          UV data                                               O111
#
#             exp 2 highest sensitive exp 3 highest sensitive  \
# index_input
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ...                             ...                     ...
# 9642                           O111                    OOOO
# 9643                           OOOO                    11O1
# 9644                           OOOO                    11O1
# 9645                           OOOO                    11OO
# 9646                           OOOO                    OOOO
#
#             exp 1 lowest sensitive exp 2 lowest sensitive  ... Unnamed: 229  \
# index_input                                                ...
# 0                              NaN                    NaN  ...          NaN
# 1                              NaN                    NaN  ...          NaN
# 2                              NaN                    NaN  ...          NaN
# 3                              NaN                    NaN  ...          NaN
# 4                              NaN                    NaN  ...          NaN
# ...                            ...                    ...  ...          ...
# 9642                          OOOO                   O111  ...          NaN
# 9643                          OOOO                   OOOO  ...          NaN
# 9644                          O111                   OOOO  ...          NaN
# 9645                          OO11                   OOOO  ...          NaN
# 9646                          O11O                   OOOO  ...          NaN
#
#             exp1 sensitive exp2 sensitive exp3 sensitive total sensitive  \
# index_input
# 0                      NaN            NaN            NaN             NaN
# 1                      NaN            NaN            NaN             NaN
# 2                      NaN            NaN            NaN             NaN
# 3                      NaN            NaN            NaN             NaN
# 4                      NaN            NaN            NaN             NaN
# ...                    ...            ...            ...             ...
# 9642                   NaN            NaN            NaN             0.0
# 9643                   NaN            NaN            NaN             0.0
# 9644                   NaN            NaN            NaN             0.0
# 9645                   NaN            NaN            NaN             0.0
# 9646                   NaN            NaN            NaN             0.0
#
#             exp1 resistant exp2 resistant  exp3 resistant total resistant  orf
# index_input
# 0                      NaN            NaN             NaN             NaN  NAN
# 1                      NaN            NaN             NaN             NaN  NAN
# 2                      NaN            NaN             NaN             NaN  NAN
# 3                      NaN            NaN             NaN             NaN  NAN
# 4                      NaN            NaN             NaN             NaN  NAN
# ...                    ...            ...             ...             ...  ...
# 9642                   NaN            NaN             NaN             0.0  NAN
# 9643                   NaN            NaN             NaN             0.0  NAN
# 9644                   NaN            NaN             NaN             0.0  NAN
# 9645                   NaN            NaN             NaN             0.0  NAN
# 9646                   NaN            NaN             NaN             0.0  NAN
#
# [2775 rows x 239 columns]

# %%
original_data = original_data.loc[t,:]

# %%
original_data['Treatment'].unique()
# Out:
# array(['MMS data', 't-BuOOH data', '4NQO data', 'UV data'], dtype=object)

# %%
data_cols = [c for c in original_data.columns if 'control/dose' in c]
data_cols
# Out:
# ['exp 1 highest control/dose 1',
#  'exp 1 highest control/dose 2',
#  'exp 1 highest control/dose 3',
#  'exp 1 highest control/dose 4',
#  'exp 1 lowest control/dose 1',
#  'exp 1 lowest control/dose 2',
#  'exp 1 lowest control/dose 3',
#  'exp 1 lowest control/dose 4',
#  'exp 2 highest control/dose 1',
#  'exp 2 highest control/dose 2',
#  'exp 2 highest control/dose 3',
#  'exp 2 highest control/dose 4',
#  'exp 2 lowest control/dose 1',
#  'exp 2 lowest control/dose 2',
#  'exp 2 \nlowest control/dose 3',
#  'exp 2 lowest control/dose 4',
#  'exp 3 highest control/dose 1',
#  'exp 3 highest control/dose 2',
#  'exp 3 highest control/dose 3',
#  'exp 3 highest control/dose 4',
#  'exp 3 lowest control/dose 1',
#  'exp 3 lowest control/dose 2',
#  'exp 3  lowest control/dose 3',
#  'exp 3 lowest control/dose 4']

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data = original_data[['Treatment'] + data_cols].copy()

# %%
original_data[data_cols] = original_data[data_cols].apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data[data_cols] = 1 / original_data[data_cols]

# %%
original_data.head()
# Out:
#         Treatment  exp 1 highest control/dose 1  exp 1 highest control/dose 2  \
# orf
# YLL001W  MMS data                      0.962230                      0.765388
# YLL002W  MMS data                      0.258894                      0.363781
# YLL005C  MMS data                      0.951988                      0.864422
# YLL006W  MMS data                      1.415584                      1.431507
# YLL009C  MMS data                      1.238819                      0.858577
#
#          exp 1 highest control/dose 3  exp 1 highest control/dose 4  \
# orf
# YLL001W                      0.461301                      0.501954
# YLL002W                      0.426277                      0.217547
# YLL005C                      0.868063                      0.586865
# YLL006W                      1.655011                      1.391692
# YLL009C                      0.646676                      0.631304
#
#          exp 1 lowest control/dose 1  exp 1 lowest control/dose 2  \
# orf
# YLL001W                     0.939675                     0.847121
# YLL002W                     0.252826                     0.402628
# YLL005C                     0.929673                     0.956730
# YLL006W                     1.382402                     1.584372
# YLL009C                     1.209781                     0.950262
#
#          exp 1 lowest control/dose 3  exp 1 lowest control/dose 4  \
# orf
# YLL001W                     0.534617                     0.476140
# YLL002W                     0.494025                     0.206359
# YLL005C                     1.006025                     0.556684
# YLL006W                     1.918044                     1.320121
# YLL009C                     0.749453                     0.598838
#
#          exp 2 highest control/dose 1  ...  exp 2 \nlowest control/dose 3  \
# orf                                    ...
# YLL001W                      0.896331  ...                       0.499864
# YLL002W                      0.092899  ...                       0.036274
# YLL005C                      0.905423  ...                       0.605620
# YLL006W                      0.924438  ...                       0.695063
# YLL009C                      0.936020  ...                       0.650659
#
#          exp 2 lowest control/dose 4  exp 3 highest control/dose 1  \
# orf
# YLL001W                     0.538637                      0.893749
# YLL002W                     0.338241                      0.114434
# YLL005C                     1.472785                      0.965942
# YLL006W                     1.544927                      1.159492
# YLL009C                     1.067021                      1.076536
#
#          exp 3 highest control/dose 2  exp 3 highest control/dose 3  \
# orf
# YLL001W                      0.988535                      0.541850
# YLL002W                      0.105153                      0.274697
# YLL005C                      1.070133                      1.047486
# YLL006W                      1.155337                      1.592441
# YLL009C                      1.172880                      1.013236
#
#          exp 3 highest control/dose 4  exp 3 lowest control/dose 1  \
# orf
# YLL001W                      0.689292                     0.918893
# YLL002W                      0.367659                     0.117653
# YLL005C                      1.461188                     0.993117
# YLL006W                      1.763183                     1.192112
# YLL009C                      1.198472                     1.106822
#
#          exp 3 lowest control/dose 2  exp 3  lowest control/dose 3  \
# orf
# YLL001W                     1.040510                      0.491908
# YLL002W                     0.110681                      0.249378
# YLL005C                     1.126398                      0.950940
# YLL006W                     1.216082                      1.445667
# YLL009C                     1.234548                      0.919846
#
#          exp 3 lowest control/dose 4
# orf
# YLL001W                     0.752138
# YLL002W                     0.401180
# YLL005C                     1.594411
# YLL006W                     1.923940
# YLL009C                     1.307742
#
# [5 rows x 25 columns]

# %%
for dose in np.arange(1,5):
    cols = [c for c in original_data.columns if 'dose ' + str(dose) in c]
    original_data['dose' + str(dose)] = original_data[cols].mean(axis=1)

# %%
treatments = original_data['Treatment'].unique()

# %%
original_data_list = []
for t in treatments:
    original_data1 = original_data.loc[original_data['Treatment']==t,['dose1','dose2','dose3','dose4']].copy()
    original_data1 = original_data1.groupby(original_data1.index).mean()
    cols = [t+'_'+c for c in original_data1.columns]
    original_data1.columns=cols
    
    original_data_list.append(original_data1)

# %%
original_data = pd.concat(original_data_list, axis=1)

# %%
original_data.shape
# Out:
# (1637, 16)

# %%
original_data.head()
# Out:
#          MMS data_dose1  MMS data_dose2  MMS data_dose3  MMS data_dose4  \
# orf
# YAL002W        0.838585        0.318535        0.195740        0.531143
# YAL004W        0.776970        0.509674        0.431777        0.991911
# YAL005C        0.795909        0.406662        0.371982        0.862050
# YAL007C        0.795636        0.653670        0.586989        1.019509
# YAL008W        0.856244        0.696004        0.582830        0.939777
#
#          t-BuOOH data_dose1  t-BuOOH data_dose2  t-BuOOH data_dose3  \
# orf
# YAL002W            0.989822            0.929084            0.933097
# YAL004W            0.983077            0.930386            1.043149
# YAL005C            0.991444            0.911259            1.102001
# YAL007C            1.008561            0.989197            1.094017
# YAL008W            1.028011            0.986614            1.118636
#
#          t-BuOOH data_dose4  4NQO data_dose1  4NQO data_dose2  \
# orf
# YAL002W            0.399308         0.895401         0.874471
# YAL004W            0.904319         0.926982         0.904787
# YAL005C            0.974523         0.921140         0.951530
# YAL007C            0.991351         0.946796         0.916957
# YAL008W            0.982803         0.966736         0.932029
#
#          4NQO data_dose3  4NQO data_dose4  UV data_dose1  UV data_dose2  \
# orf
# YAL002W         0.893056         0.782130       0.879667       0.911013
# YAL004W         1.051204         1.012846       0.892266       0.903389
# YAL005C         1.055040         1.032956       0.883057       0.899703
# YAL007C         1.057571         1.019111       0.930758       0.947015
# YAL008W         1.026638         0.982900       0.934417       0.943022
#
#          UV data_dose3  UV data_dose4
# orf
# YAL002W       0.928064       0.865901
# YAL004W       0.908228       0.857740
# YAL005C       0.912981       0.841261
# YAL007C       0.943878       0.890667
# YAL008W       0.959441       0.904148

# %%
dt = pd.read_csv('extras/phenotype_datasetids.txt', sep='\t', header=None)

# %%
dataset_ids = dt[1].values

# %%
original_data.shape
# Out:
# (1637, 16)

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id        33        34        35        36        37        38  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W     0.838585  0.318535  0.195740  0.531143  0.989822  0.929084
# YAL004W     0.776970  0.509674  0.431777  0.991911  0.983077  0.930386
# YAL005C     0.795909  0.406662  0.371982  0.862050  0.991444  0.911259
# YAL007C     0.795636  0.653670  0.586989  1.019509  1.008561  0.989197
# YAL008W     0.856244  0.696004  0.582830  0.939777  1.028011  0.986614
#
# dataset_id        39        40        41        42        43        44  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W     0.933097  0.399308  0.895401  0.874471  0.893056  0.782130
# YAL004W     1.043149  0.904319  0.926982  0.904787  1.051204  1.012846
# YAL005C     1.102001  0.974523  0.921140  0.951530  1.055040  1.032956
# YAL007C     1.094017  0.991351  0.946796  0.916957  1.057571  1.019111
# YAL008W     1.118636  0.982803  0.966736  0.932029  1.026638  0.982900
#
# dataset_id        45        46        47        48
# data_type      value     value     value     value
# orf
# YAL002W     0.879667  0.911013  0.928064  0.865901
# YAL004W     0.892266  0.903389  0.908228  0.857740
# YAL005C     0.883057  0.899703  0.912981  0.841261
# YAL007C     0.930758  0.947015  0.943878  0.890667
# YAL008W     0.934417  0.943022  0.959441  0.904148

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 9

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id             33        34        35        36        37        38  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W  0.838585  0.318535  0.195740  0.531143  0.989822  0.929084
# 1863    YAL004W  0.776970  0.509674  0.431777  0.991911  0.983077  0.930386
# 4       YAL005C  0.795909  0.406662  0.371982  0.862050  0.991444  0.911259
# 5       YAL007C  0.795636  0.653670  0.586989  1.019509  1.008561  0.989197
# 6       YAL008W  0.856244  0.696004  0.582830  0.939777  1.028011  0.986614
#
# dataset_id             39        40        41        42        43        44  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W  0.933097  0.399308  0.895401  0.874471  0.893056  0.782130
# 1863    YAL004W  1.043149  0.904319  0.926982  0.904787  1.051204  1.012846
# 4       YAL005C  1.102001  0.974523  0.921140  0.951530  1.055040  1.032956
# 5       YAL007C  1.094017  0.991351  0.946796  0.916957  1.057571  1.019111
# 6       YAL008W  1.118636  0.982803  0.966736  0.932029  1.026638  0.982900
#
# dataset_id             45        46        47        48
# data_type           value     value     value     value
# gene_id orf
# 2       YAL002W  0.879667  0.911013  0.928064  0.865901
# 1863    YAL004W  0.892266  0.903389  0.908228  0.857740
# 4       YAL005C  0.883057  0.899703  0.912981  0.841261
# 5       YAL007C  0.930758  0.947015  0.943878  0.890667
# 6       YAL008W  0.934417  0.943022  0.959441  0.904148

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=False)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id             33        34        35        36        37        38  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W  0.838585  0.318535  0.195740  0.531143  0.989822  0.929084
# 1863    YAL004W  0.776970  0.509674  0.431777  0.991911  0.983077  0.930386
# 4       YAL005C  0.795909  0.406662  0.371982  0.862050  0.991444  0.911259
# 5       YAL007C  0.795636  0.653670  0.586989  1.019509  1.008561  0.989197
# 6       YAL008W  0.856244  0.696004  0.582830  0.939777  1.028011  0.986614
#
# dataset_id             39        40        41        42  ...        39  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 2       YAL002W  0.933097  0.399308  0.895401  0.874471  ...  1.435720
# 1863    YAL004W  1.043149  0.904319  0.926982  0.904787  ...  1.611861
# 4       YAL005C  1.102001  0.974523  0.921140  0.951530  ...  1.706056
# 5       YAL007C  1.094017  0.991351  0.946796  0.916957  ...  1.693277
# 6       YAL008W  1.118636  0.982803  0.966736  0.932029  ...  1.732680
#
# dataset_id             40        41        42        43        44        45  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W  0.680390  1.321180  1.332061  0.462264  1.066172  1.444735
# 1863    YAL004W  1.468991  1.366870  1.373678  0.589243  1.353928  1.464359
# 4       YAL005C  1.578618  1.358419  1.437843  0.592324  1.379008  1.450015
# 5       YAL007C  1.604895  1.395538  1.390383  0.594356  1.361741  1.524313
# 6       YAL008W  1.591547  1.424388  1.411073  0.569519  1.316578  1.530012
#
# dataset_id             46        47        48
# data_type          valuez    valuez    valuez
# gene_id orf
# 2       YAL002W  1.506289  1.574373  1.487055
# 1863    YAL004W  1.493406  1.539000  1.473453
# 4       YAL005C  1.487176  1.547475  1.445986
# 5       YAL007C  1.567127  1.602574  1.528334
# 6       YAL008W  1.560379  1.630328  1.550804
#
# [5 rows x 32 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Deleting all datasets for PMID 12496357...
# Inserting the new data...
# 100%|██████████| 16/16 [00:40<00:00,  2.55s/it]
# Updating the data_modified_on field...
