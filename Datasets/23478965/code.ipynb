# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 23478965
paper_name = 'richie_hoepfner_2013'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
files = ['HOP-exp-scores-annotation.txt','HIP-exp-scores-annotation.txt']

# %%
original_data_list = []
for f in files:
    original_data = pd.read_csv('large_files/raw_data/' + f, sep='\t')
    print('Original data dimensions: %d x %d' % (original_data.shape))
    original_data = pd.pivot_table(original_data, index='Systematic Names', columns='Compound_conc', values='Score', fill_value=np.nan)
    print(original_data.shape)
    
    original_data['orf'] = original_data.index.values
    original_data['orf'] = clean_orf(original_data['orf'])
    original_data['orf'] = translate_sc(original_data['orf'], to='orf')
    original_data.loc['YPR099C','orf'] = 'YPR099C'
    
    t = looks_like_orf(original_data['orf'])
    print(original_data.loc[~t,])
    original_data = original_data.loc[t,:]
    original_data.set_index('orf', inplace=True)
    original_data = original_data.groupby(original_data.index).mean()
    print(original_data.shape)
    
    original_data_list.append(original_data)
# Out:
# Original data dimensions: 51262 x 28
# (4523, 11)
# Compound_conc  Chlorimuron_10  Compound1_3  Compound1_4  Compound2_6  \
# index_input
# YAR040C              0.133576    -0.016191     0.138273     0.062301
# YAR043C              0.042087     0.229566    -1.105603    -0.143871
# YCL006C             -0.023174     0.749857     0.010612     0.235295
# YCL074W             -0.050601    -0.012967     0.053645     0.043111
# YCL075W              0.030026    -0.002683     0.016945     0.027549
# YER108C             -1.123969    -0.001264    -0.065715    -0.010246
# YER109C             -0.034964    -0.151764    -0.050662    -0.320496
# YFL056C              0.298193     0.009800     1.304053     0.888849
# YIL170W             -2.080307    -6.010080    -5.886944    -9.026390
# YOR031W              0.630187    -0.006942    -0.202416     0.637861
#
# Compound_conc  Compound3_1.5  Compound4_10  Compound5_8  Compound6_0.5  \
# index_input
# YAR040C             0.342664      0.056315    -0.002482       1.055634
# YAR043C            -0.000680     -0.169081     0.001043       0.101409
# YCL006C            -0.816832     -0.131886    -0.025859       0.032032
# YCL074W            -0.059736     -1.391750    -0.908988       0.004993
# YCL075W            -0.680782     -0.046727     0.478670      -0.478654
# YER108C             0.089246     -0.041216    -1.176881      -0.141893
# YER109C            -0.213410      0.079287    -1.093167       0.007379
# YFL056C             0.154508      1.212150     0.218501       0.050700
# YIL170W             0.537331     -2.843497    -2.814434      -0.141865
# YOR031W             0.025679     -0.007738    -0.013195      -0.044757
#
# Compound_conc  Compound7_4  Compound8_4  Sulfometuron_30  orf
# index_input
# YAR040C          -0.011807    -0.014250         1.311011  NaN
# YAR043C           0.328022    -1.182585        -1.082244  NaN
# YCL006C           0.049905    -0.025807        -0.512864  NaN
# YCL074W           0.072548    -0.019857        -0.736343  NaN
# YCL075W          -0.076919    -0.013671        -0.047045  NaN
# YER108C           0.010405    -0.281603         0.004283  NaN
# YER109C          -0.016767    -0.167036        -0.088217  NaN
# YFL056C           0.072151     0.003495         0.518627  NaN
# YIL170W          -0.042952     0.010749        -0.473030  NaN
# YOR031W          -0.016001     0.003632        -0.039193  NaN
# (4505, 11)
# Original data dimensions: 64119 x 28
# (5774, 11)
# Compound_conc  Chlorimuron_10  Compound1_3  Compound1_4  Compound2_6  \
# index_input
# YAR040C             -0.313243     0.000718     0.013711    -1.645352
# YAR043C             -1.404200    -2.501148     0.000160    -0.350662
# YCL006C             -1.564826    -1.274491     0.101153    -1.435664
# YCL074W              0.001958     0.012075    -0.015012    -1.293335
# YCL075W              0.008254    -0.088210     0.003126    -0.438909
# YER108C              0.008433    -0.956774    -0.004653    -1.004558
# YER109C            -13.565619   -11.581217   -16.573930   -15.589903
# YFL056C             -0.039197     0.059502    -0.206481    -0.042937
# YIL170W             -2.567129    -9.478770   -12.491734    -9.503538
# YOR031W              0.806577     0.485929     1.075502     0.146135
#
# Compound_conc  Compound3_1.5  Compound4_10  Compound5_8  Compound6_0.5  \
# index_input
# YAR040C             0.191601      0.584716    -0.013565       0.477505
# YAR043C            -2.333593     -2.858156    -2.336389      -0.915326
# YCL006C            -2.221151     -1.073921    -1.802511       0.275044
# YCL074W            -0.056836     -0.557972    -0.083706      -0.081982
# YCL075W            -1.032321     -0.363175     0.157052      -0.594105
# YER108C            -0.180347     -0.201530     0.024197      -0.003484
# YER109C           -27.182243    -25.888551   -23.311285     -17.570923
# YFL056C            -0.059995      0.096540    -0.060896       0.049367
# YIL170W            -3.247372     -8.425402    -9.942152      -3.303751
# YOR031W            -0.008783      0.165836     0.253886       2.249450
#
# Compound_conc  Compound7_4  Compound8_4  Sulfometuron_30  orf
# index_input
# YAR040C           0.064321     0.436538         0.589842  NaN
# YAR043C          -0.165452    -0.008743        -0.758773  NaN
# YCL006C          -0.341163    -1.283510        -1.662770  NaN
# YCL074W          -0.015777    -0.006098        -0.099726  NaN
# YCL075W          -0.172059     0.002369         0.011431  NaN
# YER108C          -0.055143     0.474930        -0.357374  NaN
# YER109C         -30.991883   -22.674717       -12.428591  NaN
# YFL056C           0.035385     0.128089         0.142710  NaN
# YIL170W          -0.707780    -0.098602        -2.099844  NaN
# YOR031W          -0.038826    -0.030221         0.487070  NaN
# (5756, 11)

# %%
original_data = original_data_list[0].join(original_data_list[1], how='outer', lsuffix='_1', rsuffix='_2')

# %%
original_data.head()
# Out:
# Compound_conc  Chlorimuron_10_1  Compound1_3_1  Compound1_4_1  Compound2_6_1  \
# orf
# YAL001C                0.038991      -0.056542      -0.294365      -0.104996
# YAL002W                0.806608       0.820446       0.010005       0.119045
# YAL003W                     NaN            NaN            NaN            NaN
# YAL004W               -0.976440      -1.507391      -0.867939      -0.288604
# YAL005C                0.115980       0.005257      -0.052888      -0.169719
#
# Compound_conc  Compound3_1.5_1  Compound4_10_1  Compound5_8_1  \
# orf
# YAL001C              -1.559175       -1.422066      -0.524621
# YAL002W              -0.193387        0.031665       1.723395
# YAL003W                    NaN             NaN            NaN
# YAL004W              -0.214310       -0.041421      -0.971548
# YAL005C              -0.320672       -0.152344      -0.554363
#
# Compound_conc  Compound6_0.5_1  Compound7_4_1  Compound8_4_1  ...  \
# orf                                                           ...
# YAL001C               0.104708      -0.091587      -1.362973  ...
# YAL002W              -0.296865      -0.061796       1.077705  ...
# YAL003W                    NaN            NaN            NaN  ...
# YAL004W              -0.132192      -0.216003      -0.031660  ...
# YAL005C               0.615376      -0.005581      -0.620674  ...
#
# Compound_conc  Compound1_3_2  Compound1_4_2  Compound2_6_2  Compound3_1.5_2  \
# orf
# YAL001C             0.989844      -0.000673       0.475843         0.109321
# YAL002W            -3.417776      -2.164800      -2.048566         0.017055
# YAL003W             0.080970       0.040677      -0.255405         0.534364
# YAL004W            -2.620577      -2.515891      -2.120231        -3.099178
# YAL005C             0.257501      -1.169363       7.246556         2.860275
#
# Compound_conc  Compound4_10_2  Compound5_8_2  Compound6_0.5_2  Compound7_4_2  \
# orf
# YAL001C              0.016547       0.536540        -0.021030      -0.139963
# YAL002W             -0.020341      -2.354080        -0.007522       0.055593
# YAL003W              0.000450       0.325886         0.099893       0.071327
# YAL004W             -3.512203      -2.966133        -1.741943      -0.393509
# YAL005C              9.259456       6.642405         1.020024       5.084951
#
# Compound_conc  Compound8_4_2  Sulfometuron_30_2
# orf
# YAL001C            -0.010535           0.397133
# YAL002W             0.068183          -1.123647
# YAL003W             0.089027           0.092639
# YAL004W            -1.741337          -5.223883
# YAL005C             3.035065           4.890570
#
# [5 rows x 22 columns]

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids_hop = [16018, 16008, 16009, 16010, 16011, 16012, 16013, 16014, 16015, 16016, 16017]
dataset_ids_hip = [16029, 16019, 16020, 16021, 16022, 16023, 16024, 16025, 16026, 16027, 16028]
dataset_ids = dataset_ids_hop + dataset_ids_hip

datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id     16018     16008     16009     16010     16011     16012  \
# data_type      value     value     value     value     value     value
# orf
# YAL001C     0.038991 -0.056542 -0.294365 -0.104996 -1.559175 -1.422066
# YAL002W     0.806608  0.820446  0.010005  0.119045 -0.193387  0.031665
# YAL003W          NaN       NaN       NaN       NaN       NaN       NaN
# YAL004W    -0.976440 -1.507391 -0.867939 -0.288604 -0.214310 -0.041421
# YAL005C     0.115980  0.005257 -0.052888 -0.169719 -0.320672 -0.152344
#
# dataset_id     16013     16014     16015     16016  ...     16019     16020  \
# data_type      value     value     value     value  ...     value     value
# orf                                                 ...
# YAL001C    -0.524621  0.104708 -0.091587 -1.362973  ...  0.989844 -0.000673
# YAL002W     1.723395 -0.296865 -0.061796  1.077705  ... -3.417776 -2.164800
# YAL003W          NaN       NaN       NaN       NaN  ...  0.080970  0.040677
# YAL004W    -0.971548 -0.132192 -0.216003 -0.031660  ... -2.620577 -2.515891
# YAL005C    -0.554363  0.615376 -0.005581 -0.620674  ...  0.257501 -1.169363
#
# dataset_id     16021     16022     16023     16024     16025     16026  \
# data_type      value     value     value     value     value     value
# orf
# YAL001C     0.475843  0.109321  0.016547  0.536540 -0.021030 -0.139963
# YAL002W    -2.048566  0.017055 -0.020341 -2.354080 -0.007522  0.055593
# YAL003W    -0.255405  0.534364  0.000450  0.325886  0.099893  0.071327
# YAL004W    -2.120231 -3.099178 -3.512203 -2.966133 -1.741943 -0.393509
# YAL005C     7.246556  2.860275  9.259456  6.642405  1.020024  5.084951
#
# dataset_id     16027     16028
# data_type      value     value
# orf
# YAL001C    -0.010535  0.397133
# YAL002W     0.068183 -1.123647
# YAL003W     0.089027  0.092639
# YAL004W    -1.741337 -5.223883
# YAL005C     3.035065  4.890570
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 0

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id          16018     16008     16009     16010     16011     16012  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C  0.038991 -0.056542 -0.294365 -0.104996 -1.559175 -1.422066
# 2       YAL002W  0.806608  0.820446  0.010005  0.119045 -0.193387  0.031665
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W -0.976440 -1.507391 -0.867939 -0.288604 -0.214310 -0.041421
# 4       YAL005C  0.115980  0.005257 -0.052888 -0.169719 -0.320672 -0.152344
#
# dataset_id          16013     16014     16015     16016  ...     16019  \
# data_type           value     value     value     value  ...     value
# gene_id orf                                              ...
# 1       YAL001C -0.524621  0.104708 -0.091587 -1.362973  ...  0.989844
# 2       YAL002W  1.723395 -0.296865 -0.061796  1.077705  ... -3.417776
# 3       YAL003W       NaN       NaN       NaN       NaN  ...  0.080970
# 1863    YAL004W -0.971548 -0.132192 -0.216003 -0.031660  ... -2.620577
# 4       YAL005C -0.554363  0.615376 -0.005581 -0.620674  ...  0.257501
#
# dataset_id          16020     16021     16022     16023     16024     16025  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C -0.000673  0.475843  0.109321  0.016547  0.536540 -0.021030
# 2       YAL002W -2.164800 -2.048566  0.017055 -0.020341 -2.354080 -0.007522
# 3       YAL003W  0.040677 -0.255405  0.534364  0.000450  0.325886  0.099893
# 1863    YAL004W -2.515891 -2.120231 -3.099178 -3.512203 -2.966133 -1.741943
# 4       YAL005C -1.169363  7.246556  2.860275  9.259456  6.642405  1.020024
#
# dataset_id          16026     16027     16028
# data_type           value     value     value
# gene_id orf
# 1       YAL001C -0.139963 -0.010535  0.397133
# 2       YAL002W  0.055593  0.068183 -1.123647
# 3       YAL003W  0.071327  0.089027  0.092639
# 1863    YAL004W -0.393509 -1.741337 -5.223883
# 4       YAL005C  5.084951  3.035065  4.890570
#
# [5 rows x 22 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id          16018     16008     16009     16010     16011     16012  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C  0.038991 -0.056542 -0.294365 -0.104996 -1.559175 -1.422066
# 2       YAL002W  0.806608  0.820446  0.010005  0.119045 -0.193387  0.031665
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W -0.976440 -1.507391 -0.867939 -0.288604 -0.214310 -0.041421
# 4       YAL005C  0.115980  0.005257 -0.052888 -0.169719 -0.320672 -0.152344
#
# dataset_id          16013     16014     16015     16016  ...     16019  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 1       YAL001C -0.524621  0.104708 -0.091587 -1.362973  ...  0.857126
# 2       YAL002W  1.723395 -0.296865 -0.061796  1.077705  ... -2.732400
# 3       YAL003W       NaN       NaN       NaN       NaN  ...  0.116948
# 1863    YAL004W -0.971548 -0.132192 -0.216003 -0.031660  ... -2.083168
# 4       YAL005C -0.554363  0.615376 -0.005581 -0.620674  ...  0.260713
#
# dataset_id          16020     16021     16022     16023     16024     16025  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 1       YAL001C  0.036370  0.267268  0.132893 -0.056603  0.149708  0.072561
# 2       YAL002W -1.777897 -1.241030  0.088661 -0.072249 -1.188308  0.081683
# 3       YAL003W  0.071036 -0.169642  0.336660 -0.063431  0.052200  0.154217
# 1863    YAL004W -2.072230 -1.283849 -1.405270 -1.553343 -1.471616 -1.089515
# 4       YAL005C -0.943385  4.312670  1.451708  3.863832  2.976003  0.775551
#
# dataset_id          16026     16027     16028
# data_type          valuez    valuez    valuez
# gene_id orf
# 1       YAL001C -0.007153  0.033299  0.175264
# 2       YAL002W  0.097933  0.077784 -0.538998
# 3       YAL003W  0.106388  0.089563  0.032253
# 1863    YAL004W -0.143400 -0.944796 -2.464748
# 4       YAL005C  2.800546  1.754401  2.285687
#
# [5 rows x 44 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 23478965...
#   0%|          | 0/22 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 22/22 [03:28<00:00,  9.48s/it]
# Updating the data_modified_on field...
