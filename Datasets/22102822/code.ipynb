# %%
# %run ../yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 22102822
paper_name = 'berry_gasch_2011'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/pgen.1002353.s009.xlsx', sheet_name='Hom-Het COMPILATION')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 6128 x 94

# %%
original_data.head()
# Out:
#       YORF  DTT1 Sample1 vs Sample0 Array  DTT1 Sample2 vs Sample1 UP  \
# 0  YAL001C                         -0.050                    0.239259
# 1  YAL002W                            NaN                   -0.872710
# 2  YAL003W                          0.592                    0.253843
# 3  YAL004W                          0.209                    0.741564
# 4  YAL005C                         -0.065                    0.728445
#
#    DTT1 Sample2 vs Sample1 DN  DTT1 Sample2 vs Sample1 Array  \
# 0                         NaN                          0.034
# 1                         NaN                            NaN
# 2                         NaN                          0.007
# 3                         NaN                          0.007
# 4                         NaN                          0.045
#
#    DTT1 Sample3 vs Sample1 UP  DTT1 Sample3 vs Sample1 DN  \
# 0                   -0.013278                         NaN
# 1                    0.231187                         NaN
# 2                    0.147177                         NaN
# 3                    0.098807                         NaN
# 4                    0.376067                         NaN
#
#    DTT1 Sample3 vs Sample1 Array  DTT1 Sample4 vs Sample3 UP  \
# 0                         -0.130                    0.139765
# 1                            NaN                   -1.882254
# 2                         -0.154                    0.008348
# 3                         -0.231                    0.261632
# 4                         -0.077                    0.265845
#
#    DTT1 Sample4 vs Sample3 DN  ...  TM2 Sample1 vs Sample0 UP  \
# 0                         NaN  ...                   0.200691
# 1                         NaN  ...                   0.516988
# 2                         NaN  ...                   0.178665
# 3                         NaN  ...                   0.090227
# 4                         NaN  ...                   0.132495
#
#    TM2 Sample1 vs Sample0 DN  TM2 Sample2 vs Sample1 UP  \
# 0                        NaN                  -0.314959
# 1                        NaN                  -0.454378
# 2                        NaN                   0.652619
# 3                        NaN                   0.629178
# 4                        NaN                   0.617387
#
#    TM2 Sample2 vs Sample1 DN  TM2 Sample3 vs Sample1 UP  \
# 0                        NaN                  -0.237385
# 1                        NaN                  -1.691624
# 2                        NaN                   0.479385
# 3                        NaN                   0.369172
# 4                        NaN                   0.557833
#
#    TM2 Sample3 vs Sample1 DN  TM2 Sample4A vs Sample3 UP  \
# 0                        NaN                    0.097175
# 1                        NaN                   -1.820814
# 2                        NaN                    0.108625
# 3                        NaN                    0.081651
# 4                        NaN                    0.329289
#
#    TM2 Sample4A vs Sample3 DN  TM2 Sample4B vs Sample3 UP  \
# 0                         NaN                    0.195584
# 1                         NaN                   -2.378251
# 2                         NaN                    0.541970
# 3                         NaN                    0.119594
# 4                         NaN                    0.592264
#
#    TM2 Sample4B vs Sample3 DN
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 94 columns]

# %%
original_data['orf'] = original_data['YORF'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [YORF, DTT1 Sample1 vs Sample0 Array, DTT1 Sample2 vs Sample1 UP, DTT1 Sample2 vs Sample1 DN, DTT1 Sample2 vs Sample1 Array, DTT1 Sample3 vs Sample1 UP, DTT1 Sample3 vs Sample1 DN, DTT1 Sample3 vs Sample1 Array, DTT1 Sample4 vs Sample3 UP, DTT1 Sample4 vs Sample3 DN, DTT1 Sample4A vs Sample3 Array, DTT1 Sample4B vs Sample3 Array, DTT2 Sample1 vs Sample0 Array, DTT2 Sample2 vs Sample1 UP, DTT2 Sample2 vs Sample1 DN, DTT2 Sample2 vs Sample1 Array, DTT2 Sample3 vs Sample1 UP, DTT2 Sample3 vs Sample1 DN, DTT2 Sample3 vs Sample1 Array, DTT2 Sample4 vs Sample3 UP, DTT2 Sample4 vs Sample3 DN, DTT2 Sample4A vs Sample3 Array, DTT2 Sample4B vs Sample3 Array, NaCl1 Sample1 vs Sample0 Array, NaCl1 Sample2 vs Sample1 Array, NaCl1 Sample3 vs Sample1 Array, NaCl1 Sample4A vs Sample3 Array, NaCl2 Sample1 vs Sample0 Array, NaCl2 Sample2 vs Sample1 UP, NaCl2 Sample2 vs Sample1 DN, NaCl2 Sample2 vs Sample1 Array, NaCl2 Sample3 vs Sample1 UP, NaCl2 Sample3 vs Sample1 DN, NaCl2 Sample3 vs Sample1 Array, NaCl2 Sample4 vs Sample3 UP, NaCl2 Sample4 vs Sample3 DN, NaCl2 Sample4A vs Sample3 Array, NaCl3 Sample1 vs Sample0 Array, NaCl3 Sample2 vs Sample1 UP, NaCl3 Sample2 vs Sample1 DN, NaCl3 Sample2 vs Sample1 Array, NaCl3 Sample3 vs Sample1 UP, NaCl3 Sample3 vs Sample1 DN, NaCl3 Sample3 vs Sample1 Array, NaCl3 Sample4 vs Sample3 UP, NaCl3 Sample4 vs Sample3 DN, NaCl3 Sample4A vs Sample3 Array, NaCl3 Sample4B vs Sample3 Array, HS1 Sample1 vs Sample0 Array, HS1 Sample2 vs Sample1 Array, HS1 Sample3 vs Sample1 Array, HS1 Sample4A vs Sample1 Array, HS2 Sample1 vs Sample0 Array, HS2 Sample2 vs Sample1 UP, HS2 Sample2 vs Sample1 DN, HS2 Sample2 vs Sample1 Array, HS2 Sample3 vs Sample1 UP, HS2 Sample3 vs Sample1 DN, HS2 Sample3 vs Sample1 Array, HS2 Sample4 vs Sample3 UP, HS2 Sample4 vs Sample3 DN, HS2 Sample4A vs Sample3 Array, HS2 Sample4B vs Sample3 Array, HS3 Sample1 vs Sample0 Array, HS3 Sample2 vs Sample1 UP, HS3 Sample2 vs Sample1 DN, HS3 Sample2 vs Sample1 Array, HS3 Sample3  vs Sample1 UP, HS3 Sample3 vs Sample1 DN, HS3 Sample3 vs Sample1 Array, HS3 Sample4 vs Sample3 UP, HS3 Sample4 vs Sample3 DN, HS3 Sample4A vs Sample3 Array, HS3 Sample4B vs Sample3 Array, TM1 Sample1 vs Sample0 UP, TM1 Sample1 vs Sample0 DN, TM1 Sample2 vs Sample1 UP, TM1 Sample2 vs Sample1 DN, TM1 Sample3 vs Sample1 UP, TM1 Sample3 vs Sample1 DN, TM1 Sample4A vs Sample3 UP, TM1 Sample4A vs Sample3 DN, TM1 Sample4B vs Sample3 UP, TM1 Sample4B vs Sample3 DN, TM2 Sample1 vs Sample0 UP, TM2 Sample1 vs Sample0 DN, TM2 Sample2 vs Sample1 UP, TM2 Sample2 vs Sample1 DN, TM2 Sample3 vs Sample1 UP, TM2 Sample3 vs Sample1 DN, TM2 Sample4A vs Sample3 UP, TM2 Sample4A vs Sample3 DN, TM2 Sample4B vs Sample3 UP, TM2 Sample4B vs Sample3 DN, orf]
# Index: []
#
# [0 rows x 95 columns]

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data.drop(columns=['YORF'], inplace=True)

# %%
for c in original_data.columns:
    original_data[c] = pd.to_numeric(original_data[c], errors='coerce')

# %% [markdown]
# ## Data processing

# %%
import re

# %%
regex_list = ['Sample1 vs Sample0 Array','Sample2 vs Sample1 Array',
              'DTT[0-9] Sample3 vs Sample1 Array','NaCl[0-9] Sample3 vs Sample1 Array','HS[0-9] Sample3 vs Sample1 Array',
              'DTT[0-9] Sample4[A-Z]? vs Sample3 Array','NaCl[0-9] Sample4[A-Z]? vs Sample3 Array','HS[0-9] Sample4[A-Z]? vs Sample3 Array',
              'Sample1 vs Sample0 [(DN)(UP)]','Sample2 vs Sample1 [(DN)(UP)]','DTT[0-9] Sample3 vs Sample1 [(DN)(UP)]',
              'NaCl[0-9] Sample3 vs Sample1 [(DN)(UP)]','HS[0-9] Sample3 vs Sample1 [(DN)(UP)]','TM[0-9] Sample3 vs Sample1 [(DN)(UP)]',
              'DTT[0-9] Sample4[A-Z]? vs Sample3 [(DN)(UP)]','NaCl[0-9] Sample4[A-Z]? vs Sample3 [(DN)(UP)]',
              'HS[0-9] Sample4[A-Z]? vs Sample3 [(DN)(UP)]','TM[0-9] Sample4[A-Z]? vs Sample3 [(DN)(UP)]']

# %%
original_data_list = []
for r in regex_list:
    data_cols = [c for c in original_data.columns if bool(re.search(r, c))]
    t = original_data[data_cols].mean(axis=1)
    original_data_list.append(t)

# %%
original_data = pd.concat(original_data_list, axis=1)

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
### Only keep Hom strains using current Hom collection from Open Biosystems
hom = pd.read_excel('extras/Homozygous_diploid_obs_v7.0.xlsx', sheet_name='DATA')
hom.head()
# Out:
#   Record number      ORF   Batch Collection  Plate Row Col Comment
# 0         30916  YHL047C  chr8_1    Hom Dip      1   A   2     NaN
# 1         30917  YHL046C  chr8_1    Hom Dip      1   A   3     NaN
# 2         30918  YHL045W  chr8_1    Hom Dip      1   A   4     NaN
# 3         30919  YHL044W  chr8_1    Hom Dip      1   A   5     NaN
# 4         30920  YHL043W  chr8_1    Hom Dip      1   A   6     NaN

# %%
hom['orf'] = hom['ORF'].astype(str)

# %%
hom['orf'] = clean_orf(hom['orf'])

# %%
hom['orf'] = translate_sc(hom['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(hom['orf'])
print(hom.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [Record number, ORF, Batch, Collection, Plate, Row, Col, Comment, orf]
# Index: []

# %%
hom_orfs = hom['orf'].unique()

# %%
hom_orfs_in_data = [orf for orf in hom_orfs if orf in original_data.index.values]
len(hom_orfs_in_data)
# Out:
# 4881

# %%
original_data = original_data.reindex(index=hom_orfs_in_data, fill_value=np.nan)

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = [758, 759, 761, 760, 762, 590, 588, 589, 5395, 5396, 5397, 5398, 5399, 5400, 5401, 5402, 5403, 5404]
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id      758       759     761       760       762      590       588   \
# data_type      value     value   value     value     value    value     value
# orf
# YHL047C     0.114142  0.030021  0.0530 -0.024211 -0.150000 -0.00825  0.031456
# YHL046C     0.068473  0.073602 -0.1105  0.057596  0.082500  0.17875  0.039997
# YHL045W    -0.083522  0.005647  0.1135 -0.058596 -0.062667  0.01375  0.116899
# YHL044W     0.289350 -0.419090 -0.3190 -0.267929 -0.260000 -0.43450 -0.080897
# YHL043W    -0.033187 -0.075945  0.0120  0.024357 -0.153000  0.04800 -0.048165
#
# dataset_id     589       5395      5396      5397      5398      5399  \
# data_type     value     value     value     value     value     value
# orf
# YHL047C     0.15400  0.603629  0.285873  1.872119  0.204267 -0.238393
# YHL046C    -0.31250  0.414970  0.072080 -0.780107  0.047117  0.019370
# YHL045W     0.13600  0.523496 -0.063968  0.056197 -0.204267  0.087238
# YHL044W    -0.31200  0.371554 -0.355122 -0.769061 -0.620288 -0.189663
# YHL043W    -0.04925  0.399952  0.067354 -0.294231 -0.001626 -0.575725
#
# dataset_id      5400      5401      5402      5403      5404
# data_type      value     value     value     value     value
# orf
# YHL047C    -2.630192  0.001390 -0.455216 -0.125437  1.520940
# YHL046C     0.535437  0.616131  0.340260 -0.010614  0.047467
# YHL045W     0.150231  0.223460  0.154379  0.063613  0.267529
# YHL044W     1.936132  0.771208 -0.712168 -0.208608  0.576540
# YHL043W     0.125253  0.721306 -0.055458  0.193834  0.274431

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 23

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id           758       759     761       760       762      590   \
# data_type           value     value   value     value     value    value
# gene_id orf
# 964     YHL047C  0.114142  0.030021  0.0530 -0.024211 -0.150000 -0.00825
# 963     YHL046C  0.068473  0.073602 -0.1105  0.057596  0.082500  0.17875
# 962     YHL045W -0.083522  0.005647  0.1135 -0.058596 -0.062667  0.01375
# 961     YHL044W  0.289350 -0.419090 -0.3190 -0.267929 -0.260000 -0.43450
# 960     YHL043W -0.033187 -0.075945  0.0120  0.024357 -0.153000  0.04800
#
# dataset_id           588      589       5395      5396      5397      5398  \
# data_type           value    value     value     value     value     value
# gene_id orf
# 964     YHL047C  0.031456  0.15400  0.603629  0.285873  1.872119  0.204267
# 963     YHL046C  0.039997 -0.31250  0.414970  0.072080 -0.780107  0.047117
# 962     YHL045W  0.116899  0.13600  0.523496 -0.063968  0.056197 -0.204267
# 961     YHL044W -0.080897 -0.31200  0.371554 -0.355122 -0.769061 -0.620288
# 960     YHL043W -0.048165 -0.04925  0.399952  0.067354 -0.294231 -0.001626
#
# dataset_id           5399      5400      5401      5402      5403      5404
# data_type           value     value     value     value     value     value
# gene_id orf
# 964     YHL047C -0.238393 -2.630192  0.001390 -0.455216 -0.125437  1.520940
# 963     YHL046C  0.019370  0.535437  0.616131  0.340260 -0.010614  0.047467
# 962     YHL045W  0.087238  0.150231  0.223460  0.154379  0.063613  0.267529
# 961     YHL044W -0.189663  1.936132  0.771208 -0.712168 -0.208608  0.576540
# 960     YHL043W -0.575725  0.125253  0.721306 -0.055458  0.193834  0.274431

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id           758       759     761       760       762      590   \
# data_type           value     value   value     value     value    value
# gene_id orf
# 964     YHL047C  0.114142  0.030021  0.0530 -0.024211 -0.150000 -0.00825
# 963     YHL046C  0.068473  0.073602 -0.1105  0.057596  0.082500  0.17875
# 962     YHL045W -0.083522  0.005647  0.1135 -0.058596 -0.062667  0.01375
# 961     YHL044W  0.289350 -0.419090 -0.3190 -0.267929 -0.260000 -0.43450
# 960     YHL043W -0.033187 -0.075945  0.0120  0.024357 -0.153000  0.04800
#
# dataset_id           588      589       5395      5396  ...      5395  \
# data_type           value    value     value     value  ...    valuez
# gene_id orf                                             ...
# 964     YHL047C  0.031456  0.15400  0.603629  0.285873  ...  0.140718
# 963     YHL046C  0.039997 -0.31250  0.414970  0.072080  ... -0.025326
# 962     YHL045W  0.116899  0.13600  0.523496 -0.063968  ...  0.070191
# 961     YHL044W -0.080897 -0.31200  0.371554 -0.355122  ... -0.063537
# 960     YHL043W -0.048165 -0.04925  0.399952  0.067354  ... -0.038543
#
# dataset_id           5396      5397      5398      5399      5400      5401  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 964     YHL047C  0.282097  3.958126  0.570707 -0.582740 -2.042343 -0.416363
# 963     YHL046C -0.098878 -1.391112  0.193088 -0.022870  0.350388  0.594405
# 962     YHL045W -0.341313  0.295618 -0.410968  0.124543  0.059231 -0.051231
# 961     YHL044W -0.860143 -1.368834 -1.410635 -0.476897  1.409098  0.849385
# 960     YHL043W -0.107299 -0.411156  0.075963 -1.315437  0.040352  0.767335
#
# dataset_id           5402      5403      5404
# data_type          valuez    valuez    valuez
# gene_id orf
# 964     YHL047C -1.017740 -0.382026  1.357240
# 963     YHL046C  0.451304 -0.188633 -0.105572
# 962     YHL045W  0.108029 -0.063614  0.112897
# 961     YHL044W -1.492265 -0.522110  0.419672
# 960     YHL043W -0.279487  0.155717  0.119750
#
# [5 rows x 36 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# Deleting all datasets for PMID 22102822...
# Inserting the new data...
# 100%|██████████| 18/18 [02:18<00:00,  7.70s/it]
# Updating the data_modified_on field...
