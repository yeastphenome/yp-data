# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 20065090
paper_name = 'vizeacoumar_andrews_2010'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/JCB_200909013_TableS3.xlsx', sheet_name='Single deletion screen', skiprows=1)

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4292 x 91

# %%
original_data.head()
# Out:
#   Open reading frame  Unbud cell Mean Area  Unbud cell Mean Perimeter  \
# 0            YAL002W               16.4598                    14.5957
# 1            YAL004W               15.0917                    14.0820
# 2            YAL005C               17.5131                    15.1479
# 3            YAL007C               17.1216                    14.9912
# 4            YAL008W               16.4443                    14.6618
#
#    Unbud cell Mean Length  Unbud cell Mean Breadth  \
# 0                  5.1599                   4.4408
# 1                  5.0177                   4.2465
# 2                  5.3700                   4.6191
# 3                  5.2408                   4.6086
# 4                  5.1068                   4.5370
#
#    Unbud cell Mean ShapeFactor  Unbud cell Mean Ell. Form Factor  \
# 0                       0.9444                            1.1684
# 1                       0.9420                            1.1860
# 2                       0.9465                            1.1633
# 3                       0.9469                            1.1364
# 4                       0.9500                            1.1290
#
#    Unbud cell Mean Equiv. Prolate Vol.  Unbud cell Mean Oblate Vol.  \
# 0                              66.8069                      57.6282
# 1                              58.5257                      49.5503
# 2                              72.9691                      62.4873
# 3                              68.9804                      60.2137
# 4                              64.5065                      57.2782
#
#    Medium bud Mean Mother Area  ...  Small bud Mean Mother Equiv. Oblate Vol.  \
# 0                      20.7160  ...                                   78.7655
# 1                      20.3515  ...                                   69.3222
# 2                      25.9946  ...                                    0.0000
# 3                      21.1542  ...                                   84.2858
# 4                      21.8016  ...                                   75.2070
#
#    Small bud Mean Daughter Area  Small bud Mean Daughter Perimeter  \
# 0                        5.3280                             8.3640
# 1                        3.7117                             6.5693
# 2                        0.0000                             0.0000
# 3                        4.6216                             7.4748
# 4                        1.7950                             3.5315
#
#    Small bud Mean Daughter Length  Small bud Mean Daughter Breadth  \
# 0                          3.2135                           2.5105
# 1                          2.6632                           1.9443
# 2                          0.0000                           0.0000
# 3                          2.8422                           2.4532
# 4                          1.4525                           1.0110
#
#    Small bud Mean Daughter Shape Factor  \
# 0                                0.9535
# 1                                0.8687
# 2                                0.0000
# 3                                0.9918
# 4                                0.4520
#
#    Small bud Mean Daughter Ell. Form Factor  \
# 0                                    1.2780
# 1                                    1.2565
# 2                                    0.0000
# 3                                    1.1564
# 4                                    0.7185
#
#    Small bud Mean Daughter Equiv. Prolate Vol.  \
# 0                                      13.8275
# 1                                       9.0859
# 2                                       0.0000
# 3                                      10.5986
# 4                                       4.4675
#
#    Small bud Mean Daughter Equiv. Oblate Vol.  Small bud Mean budneck width
# 0                                     10.7595                        4.1525
# 1                                      6.5652                        1.5404
# 2                                      0.0000                        0.0000
# 3                                      9.0960                        1.6706
# 4                                      3.1090                        3.3340
#
# [5 rows x 91 columns]

# %%
original_data['orf'] = original_data['Open reading frame'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [Open reading frame, Unbud cell Mean Area, Unbud cell Mean Perimeter, Unbud cell Mean Length, Unbud cell Mean Breadth, Unbud cell Mean ShapeFactor, Unbud cell Mean Ell. Form Factor, Unbud cell Mean Equiv. Prolate Vol., Unbud cell Mean Oblate Vol., Medium bud Mean Mother Area, Medium bud Mean Mother Perimeter, Medium bud Mean Mother Length, Medium bud Mean Mother Breadth, Medium bud Mean Mother Shape Factor, Medium bud Mean Mother Ell. Form Factor, Medium bud Mean Mother Equiv. Prolate Vol., Medium bud Mean Mother Equiv. Oblate Vol., Medium bud Mean Daughter Area, Medium bud Mean Daughter Perimeter, Medium bud Mean Daughter Length, Medium bud Mean Daughter Breadth, Medium bud Mean Daughter Shape Factor, Medium bud Mean Daughter Ell. Form Factor, Medium bud Mean Daughter Equiv. Prolate Vol., Medium bud Mean Daughter Equiv. Oblate Vol., Medium bud Mean budneck width, Large bud Mean Mother Area, Large bud Mean Mother Perimeter, Large bud Mean Mother Length, Large bud Mean Mother Breadth, Large bud Mean Mother Shape Factor, Large bud Mean Mother Ell. Form Factor, Large bud Mean Mother Equiv. Prolate Vol., Large bud Mean Mother Equiv. Oblate Vol., Large bud Mean Daughter Area, Large bud Mean Daughter Perimeter, Large bud Mean Daughter Length, Large bud Mean Daughter Breadth, Large bud Mean Daughter Shape Factor, Large bud Mean Daughter Ell. Form Factor, Large bud Mean Daughter Equiv. Prolate Vol., Large bud Mean Daughter Equiv. Oblate Vol., Large bud Mean budneck width, Large Bud Anaphase Spindle Mean Fiber Length, Large Bud Anaphase Spindle Mean Spindle dist to Budneck, Large Bud Anaphase Spindle Mean Spindle Orientation, Large Bud Metaphase Spindle Mean Fiber Length, Large Bud Metaphase Spindle Mean Spindle dist to Budneck, Large Bud Metaphase Spindle Mean Spindle Orientation, Medium Bud Anaphase Spindle Mean Fiber Length, Medium Bud Anaphase Spindle Mean Spindle dist to Budneck, Medium Bud Anaphase Spindle Mean Spindle Orientation, Medium Bud Metaphase Spindle Mean Fiber Length, Medium Bud Metaphase Spindle Mean Spindle dist to Budneck, Medium Bud Metaphase Spindle Mean Spindle Orientation, Small Bud Anaphase Spindle Mean Fiber Length, Small Bud Anaphase Spindle Mean Spindle dist to Budneck, Small Bud Anaphase Spindle Mean Spindle Orientation, Small Bud Metaphase Spindle Mean Fiber Length, Small Bud Metaphase Spindle Mean Spindle dist to Budneck, Small Bud Metaphase Spindle Mean Spindle Orientation, Percentage of Unbud , Percentage of Small bud, Percentage of Medium Bud, Percentage of Large Bud, Percentage of Unbud with 1 SPB, Percentage of Unbud with 2 SPB, Percentage of Unbud with more than 2 SPB, Percentage of Large Bud with Anaphase Spindle, Percentage of Large Bud with Metaphase Spindle, Percentage of Medium Bud with Anaphase Spindle, Percentage of Medium Bud with Metaphase Spindle, Percentage of Small Bud with Anaphase Spindle, Percentage of Small Bud with Metaphase Spindle, Small bud Mean Mother Area, Small bud Mean Mother Perimeter, Small bud Mean Mother Length, Small bud Mean Mother Breadth, Small bud Mean Mother Shape Factor, Small bud Mean Mother Ell. Form Factor, Small bud Mean Mother Equiv. Prolate Vol., Small bud Mean Mother Equiv. Oblate Vol., Small bud Mean Daughter Area, Small bud Mean Daughter Perimeter, Small bud Mean Daughter Length, Small bud Mean Daughter Breadth, Small bud Mean Daughter Shape Factor, Small bud Mean Daughter Ell. Form Factor, Small bud Mean Daughter Equiv. Prolate Vol., Small bud Mean Daughter Equiv. Oblate Vol., Small bud Mean budneck width, orf]
# Index: []
#
# [0 rows x 92 columns]

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data.drop(columns=['Open reading frame'], inplace=True)

# %%
original_data = original_data.apply(pd.to_numeric, axis=1, errors='coerce')

# %%
# Set all zeros to NaNs (distribution analysis suggests that zeros are
# technical artefacts, not real biological phenotypes)
original_data[original_data==0] = np.nan

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4267, 90)

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = np.arange(16036, 16126)
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id    16036    16037   16038   16039   16040   16041    16042  \
# data_type     value    value   value   value   value   value    value
# orf
# YAL002W     16.4598  14.5957  5.1599  4.4408  0.9444  1.1684  66.8069
# YAL004W     15.0917  14.0820  5.0177  4.2465  0.9420  1.1860  58.5257
# YAL005C     17.5131  15.1479  5.3700  4.6191  0.9465  1.1633  72.9691
# YAL007C     17.1216  14.9912  5.2408  4.6086  0.9469  1.1364  68.9804
# YAL008W     16.4443  14.6618  5.1068  4.5370  0.9500  1.1290  64.5065
#
# dataset_id    16043    16044    16045  ...    16116   16117   16118   16119  \
# data_type     value    value    value  ...    value   value   value   value
# orf                                    ...
# YAL002W     57.6282  20.7160  16.6978  ...  78.7655  5.3280  8.3640  3.2135
# YAL004W     49.5503  20.3515  16.6896  ...  69.3222  3.7117  6.5693  2.6632
# YAL005C     62.4873  25.9946  18.6444  ...      NaN     NaN     NaN     NaN
# YAL007C     60.2137  21.1542  16.9962  ...  84.2858  4.6216  7.4748  2.8422
# YAL008W     57.2782  21.8016  17.2180  ...  75.2070  1.7950  3.5315  1.4525
#
# dataset_id   16120   16121   16122    16123    16124   16125
# data_type    value   value   value    value    value   value
# orf
# YAL002W     2.5105  0.9535  1.2780  13.8275  10.7595  4.1525
# YAL004W     1.9443  0.8687  1.2565   9.0859   6.5652  1.5404
# YAL005C        NaN     NaN     NaN      NaN      NaN     NaN
# YAL007C     2.4532  0.9918  1.1564  10.5986   9.0960  1.6706
# YAL008W     1.0110  0.4520  0.7185   4.4675   3.1090  3.3340
#
# [5 rows x 90 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 22

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id         16036    16037   16038   16039   16040   16041    16042  \
# data_type          value    value   value   value   value   value    value
# gene_id orf
# 2       YAL002W  16.4598  14.5957  5.1599  4.4408  0.9444  1.1684  66.8069
# 1863    YAL004W  15.0917  14.0820  5.0177  4.2465  0.9420  1.1860  58.5257
# 4       YAL005C  17.5131  15.1479  5.3700  4.6191  0.9465  1.1633  72.9691
# 5       YAL007C  17.1216  14.9912  5.2408  4.6086  0.9469  1.1364  68.9804
# 6       YAL008W  16.4443  14.6618  5.1068  4.5370  0.9500  1.1290  64.5065
#
# dataset_id         16043    16044    16045  ...    16116   16117   16118  \
# data_type          value    value    value  ...    value   value   value
# gene_id orf                                 ...
# 2       YAL002W  57.6282  20.7160  16.6978  ...  78.7655  5.3280  8.3640
# 1863    YAL004W  49.5503  20.3515  16.6896  ...  69.3222  3.7117  6.5693
# 4       YAL005C  62.4873  25.9946  18.6444  ...      NaN     NaN     NaN
# 5       YAL007C  60.2137  21.1542  16.9962  ...  84.2858  4.6216  7.4748
# 6       YAL008W  57.2782  21.8016  17.2180  ...  75.2070  1.7950  3.5315
#
# dataset_id        16119   16120   16121   16122    16123    16124   16125
# data_type         value   value   value   value    value    value   value
# gene_id orf
# 2       YAL002W  3.2135  2.5105  0.9535  1.2780  13.8275  10.7595  4.1525
# 1863    YAL004W  2.6632  1.9443  0.8687  1.2565   9.0859   6.5652  1.5404
# 4       YAL005C     NaN     NaN     NaN     NaN      NaN      NaN     NaN
# 5       YAL007C  2.8422  2.4532  0.9918  1.1564  10.5986   9.0960  1.6706
# 6       YAL008W  1.4525  1.0110  0.4520  0.7185   4.4675   3.1090  3.3340
#
# [5 rows x 90 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id         16036    16037   16038   16039   16040   16041    16042  \
# data_type          value    value   value   value   value   value    value
# gene_id orf
# 2       YAL002W  16.4598  14.5957  5.1599  4.4408  0.9444  1.1684  66.8069
# 1863    YAL004W  15.0917  14.0820  5.0177  4.2465  0.9420  1.1860  58.5257
# 4       YAL005C  17.5131  15.1479  5.3700  4.6191  0.9465  1.1633  72.9691
# 5       YAL007C  17.1216  14.9912  5.2408  4.6086  0.9469  1.1364  68.9804
# 6       YAL008W  16.4443  14.6618  5.1068  4.5370  0.9500  1.1290  64.5065
#
# dataset_id         16043    16044    16045  ...     16116     16117     16118  \
# data_type          value    value    value  ...    valuez    valuez    valuez
# gene_id orf                                 ...
# 2       YAL002W  57.6282  20.7160  16.6978  ... -0.107933  0.859506  0.378298
# 1863    YAL004W  49.5503  20.3515  16.6896  ... -0.408120 -0.387536 -0.551745
# 4       YAL005C  62.4873  25.9946  18.6444  ...       NaN       NaN       NaN
# 5       YAL007C  60.2137  21.1542  16.9962  ...  0.067549  0.314490 -0.082500
# 6       YAL008W  57.2782  21.8016  17.2180  ... -0.221052 -1.866349 -2.125981
#
# dataset_id          16119     16120     16121     16122     16123     16124  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W  0.383625  0.414772 -0.054623  0.391192  0.940514  0.971374
# 1863    YAL004W -0.371177 -0.564903 -0.409472  0.314809 -0.195399 -0.221206
# 4       YAL005C       NaN       NaN       NaN       NaN       NaN       NaN
# 5       YAL007C -0.125657  0.315628  0.105645 -0.040817  0.166989  0.498385
# 6       YAL008W -2.031796 -2.179759 -2.153168 -1.596544 -1.301797 -1.203920
#
# dataset_id          16125
# data_type          valuez
# gene_id orf
# 2       YAL002W  2.913516
# 1863    YAL004W -0.313453
# 4       YAL005C       NaN
# 5       YAL007C -0.152605
# 6       YAL008W  1.902347
#
# [5 rows x 180 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 20065090...
#   0%|          | 0/90 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 90/90 [09:26<00:00,  6.29s/it]
# Updating the data_modified_on field...
