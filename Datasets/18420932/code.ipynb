# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 18420932
paper_name = 'hillenmeyer_giaever_2008'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_csv('raw_data/hom.ratio_result_nm.pub', sep='\t')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4769 x 419

# %%
original_data.head()
# Out:
#               Orf  01_05_31_04:37 degrees C::::::5gen:hom_05_01:old scanner  \
# 0  YAL002W:chr1_1                                           0.364085
# 1  YAL004W:chr1_1                                           0.033485
# 2  YAL005C:chr1_1                                           0.139571
# 3  YAL007C:chr1_1                                           0.003243
# 4  YAL008W:chr1_1                                          -0.141538
#
#    01_06_08_04:25 degrees C::::::5gen:hom_05_01:old scanner  \
# 0                                           0.217003
# 1                                          -0.012100
# 2                                          -0.189006
# 3                                          -0.196491
# 4                                          -0.124237
#
#    01_06_13_05:37 degrees C::::::20gen:hom_05_01:old scanner  \
# 0                                           4.830930
# 1                                           0.195237
# 2                                           0.232050
# 3                                           0.017423
# 4                                          -0.179533
#
#    01_06_13_07:37 degrees C::::::20gen:hom_05_01:old scanner  \
# 0                                           0.726460
# 1                                          -0.145415
# 2                                           0.322059
# 3                                           0.321070
# 4                                           0.170207
#
#    01_06_14_02:25 degrees C::::::15gen:hom_05_01:old scanner  \
# 0                                          -0.050712
# 1                                          -0.271582
# 2                                           0.200959
# 3                                           0.096454
# 4                                          -0.146000
#
#    01_06_14_05:YP glycerol::::::5gen:hom_05_01:old scanner  \
# 0                                           0.348772
# 1                                          -0.206185
# 2                                           0.033194
# 3                                          -0.013857
# 4                                           0.116082
#
#    01_06_14_07:YP glycerol::::::15gen:hom_05_01:old scanner  \
# 0                                           0.794952
# 1                                          -0.145804
# 2                                           0.316956
# 3                                           0.224222
# 4                                           0.114850
#
#    01_06_19_04:37 degrees C::::::5gen:hom_05_01:old scanner  \
# 0                                           0.514168
# 1                                          -0.093771
# 2                                          -0.192362
# 3                                          -0.189666
# 4                                           0.042651
#
#    01_06_26_08:23 degrees C::::::5gen:hom_05_01:old scanner  ...  \
# 0                                          -0.055234         ...
# 1                                          -0.160824         ...
# 2                                          -0.014067         ...
# 3                                          -0.144568         ...
# 4                                          -0.198230         ...
#
#    05_03_25_03:pH7.5::::::-5gen:hom_09_02:new scanner  \
# 0                                          -0.368424
# 1                                          -0.104239
# 2                                           0.009421
# 3                                           0.110600
# 4                                           0.147140
#
#    05_03_25_04:pH7.5:::FK506:1:ug/ml:-5gen:hom_09_02:new scanner  \
# 0                                          -0.125664
# 1                                          -0.144162
# 2                                          -0.383229
# 3                                          -0.012451
# 4                                          -0.033892
#
#    05_04_20_01:LiCl:100:mm::::-5gen:hom_09_02:new scanner  \
# 0                                          -0.130201
# 1                                          -0.136239
# 2                                           0.110520
# 3                                           0.259923
# 4                                          -0.082580
#
#    05_05_13_07:benzaldehyde:0.003:%::::-5gen:hom_09_02:new scanner  \
# 0                                           0.028618
# 1                                          -0.044624
# 2                                           0.101179
# 3                                          -0.177298
# 4                                          -0.047452
#
#    05_05_13_09:potassium disulfite:2500:um::::-5gen:hom_09_02:new scanner  \
# 0                                           0.462203
# 1                                          -0.152248
# 2                                           0.061872
# 3                                          -0.006372
# 4                                           0.101940
#
#    05_05_13_10:curcumin:150:um::::-5gen:hom_09_02:new scanner  \
# 0                                          -0.031867
# 1                                          -0.312474
# 2                                          -0.107803
# 3                                          -0.377835
# 4                                          -0.251088
#
#    05_05_13_11:thimerosal:125:nm::::-5gen:hom_09_02:new scanner  \
# 0                                          -0.098010
# 1                                          -0.300317
# 2                                           0.090859
# 3                                           0.113757
# 4                                           0.069136
#
#    05_05_13_12:bisphenol:125:um::::-5gen:hom_09_02:new scanner  \
# 0                                           0.005553
# 1                                          -0.139599
# 2                                           0.205231
# 3                                          -0.015115
# 4                                          -0.131789
#
#    05_08_09_05:myriocin:0.2:ug/ml::::-5gen:hom_09_02:new scanner  \
# 0                                          -1.113940
# 1                                          -0.218166
# 2                                          -0.776672
# 3                                          -0.224341
# 4                                           0.007551
#
#    05_08_09_06:aureobasidin A:0.02:ug/ml::::-5gen:hom_09_02:new scanner
# 0                                          -0.212757
# 1                                          -0.315431
# 2                                          -0.386412
# 3                                          -0.239957
# 4                                          -0.202616
#
# [5 rows x 419 columns]

# %%
original_data['orf'] = original_data['Orf'].apply(lambda x: x.split(':')[0])

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [Orf, 01_05_31_04:37 degrees C::::::5gen:hom_05_01:old scanner, 01_06_08_04:25 degrees C::::::5gen:hom_05_01:old scanner, 01_06_13_05:37 degrees C::::::20gen:hom_05_01:old scanner, 01_06_13_07:37 degrees C::::::20gen:hom_05_01:old scanner, 01_06_14_02:25 degrees C::::::15gen:hom_05_01:old scanner, 01_06_14_05:YP glycerol::::::5gen:hom_05_01:old scanner, 01_06_14_07:YP glycerol::::::15gen:hom_05_01:old scanner, 01_06_19_04:37 degrees C::::::5gen:hom_05_01:old scanner, 01_06_26_08:23 degrees C::::::5gen:hom_05_01:old scanner, 01_06_26_10:YP glycerol::::::5gen:hom_05_01:old scanner, 01_06_28_04:YP glycerol::::::15gen:hom_05_01:old scanner, 01_06_29_03:23 degrees C::::::15gen:hom_05_01:old scanner, 01_07_17_03:23 degrees C::::::15gen:hom_05_01:old scanner, 01_07_24_08:37 degrees C::::::5gen:hom_05_01:old scanner, 01_07_24_09:37 degrees C::::::20gen:hom_05_01:old scanner, 01_07_27_18:pH8::::::20gen:hom_05_01:old scanner, 01_07_27_19:sorbitol:1.5e+06:um::::5gen:hom_05_01:old scanner, 01_07_27_20:sorbitol:1.5e+06:um::::20gen:hom_05_01:old scanner, 01_07_27_21:minimal media::::::5gen:hom_05_01:old scanner, 01_07_27_22:minimal media::::::20gen:hom_05_01:old scanner, 01_08_28_11:nystatin:5:um::::20gen:hom_05_01:old scanner, 01_09_14_05:5-fluorouracil:38.46:um::::15gen:hom_05_01:old scanner, 01_09_14_06:5-fluorouracil:19.2:um::::15gen:hom_05_01:old scanner, 01_09_14_07:5-fluorouracil:9.6:um::::20gen:hom_05_01:old scanner, 01_09_18_04:cisplatin:125:um::::20gen:hom_05_01:old scanner, 01_09_18_05:clotrimazole:2:um::::20gen:hom_05_01:old scanner, 01_09_18_06:clotrimazole:1:um::::20gen:hom_05_01:old scanner, 01_09_18_07:miconazole:50:nm::::20gen:hom_05_01:old scanner, 01_09_18_08:miconazole:25:nm::::20gen:hom_05_01:old scanner, 01_09_19_05:miconazole:100:um::::20gen:hom_05_01:old scanner, 01_11_20_05:minimal media:400:um::::15gen:hom_05_01:old scanner, 01_11_20_06:nitric oxide::::::20gen:hom_05_01:old scanner, 01_11_20_07:nitric oxide::::::20gen:hom_05_01:old scanner, 01_11_28_01:sorbitol:1.5e+06:um::::5gen:hom_05_01:old scanner, 01_11_28_02:sorbitol:1.5e+06:um::::15gen:hom_05_01:old scanner, 01_11_28_03:minimal media::::::15gen:hom_05_01:old scanner, 01_11_28_04:minimal media::::::20gen:hom_05_01:old scanner, 01_12_04_01:nystatin:10:um::::5gen:hom_05_01:old scanner, 01_12_04_02:nystatin:10:um::::5gen:hom_05_01:old scanner, 01_12_04_03:nystatin:10:um::::15gen:hom_05_01:old scanner, 01_12_04_04:nystatin:10:um::::15gen:hom_05_01:old scanner, 01_12_11_01:sorbitol:1.5e+06:um::::15gen:hom_05_01:old scanner, 01_12_11_02:sorbitol:1.5:m::::15gen:hom_05_01:old scanner, 01_12_11_03:NaCl:1000:um::::15gen:hom_05_01:old scanner, 01_12_11_04:NaCl:1000:um::::15gen:hom_05_01:old scanner, 01_12_11_05:pH8::::::15gen:hom_05_01:old scanner, 01_12_11_06:pH8::::::15gen:hom_05_01:old scanner, 01_12_13_01:sorbitol:1.5e+06:um::::15gen:hom_05_01:old scanner, 01_12_13_02:pH8::::::15gen:hom_05_01:old scanner, 02_01_23_04:tryptophan dropout::::::15gen:hom_05_01:old scanner, 02_01_23_05:synthetic complete::::::15gen:hom_05_01:old scanner, 02_01_29_01:synthetic complete::::::15gen:hom_05_01:old scanner, 02_01_29_02:lysine dropout::::::20gen:hom_05_01:old scanner, 02_01_30_02:synthetic complete::::::15gen:hom_05_01:old scanner, 02_01_30_03:lysine dropout::::::20gen:hom_05_01:old scanner, 02_02_05_01:synthetic complete::::::5gen:hom_05_01:old scanner, 02_02_05_02:lysine dropout::::::5gen:hom_05_01:old scanner, 02_02_05_03:tryptophan dropout::::::5gen:hom_05_01:old scanner, 02_02_05_04:arginine dropout::::::5gen:hom_05_01:old scanner, 02_02_05_05:adenine dropout::::::5gen:hom_05_01:old scanner, 02_02_05_06:isoleucine dropout::::::5gen:hom_05_01:old scanner, 02_02_07_01:synthetic complete::::::5gen:hom_05_01:old scanner, 02_02_07_02:lysine dropout::::::5gen:hom_05_01:old scanner, 02_02_07_03:tryptophan dropout::::::5gen:hom_05_01:old scanner, 02_02_07_04:threonine dropout::::::5gen:hom_05_01:old scanner, 02_02_07_05:tyrosine dropout::::::5gen:hom_05_01:old scanner, 02 ...
# Index: []
#
# [0 rows x 420 columns]

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data.drop(columns=['Orf'], inplace=True)

# %%
original_data = original_data.apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4717, 418)

# %% [markdown]
# ## Load dataset ids

# %%
dt = pd.read_csv('extras/datasets.txt', sep='\t', header=None)

# %%
dt[0] = pd.to_numeric(dt[0], errors='coerce')
dt.head()
# Out:
#        0                                                  1
# 0  779.0  04_02_11_14:1,3-diallylurea:10000:um::::20gen:...
# 1  778.0  04_01_14_05:1,3-diallylurea:20000:um::::20gen:...
# 2  780.0  03_12_09_02:1,4-dimethylendothall:100:um::::20...
# 3  781.0  04_01_14_06:1,7-octadiene:0.25:%::::20gen:hom_...
# 4  782.0  04_02_11_13:1,8-nonadiene:0.49:%::::20gen:hom_...

# %%
dt_ids = np.array([dt.loc[dt[1]==c,0].values[0] for c in original_data.columns.values])

# %%
dt_ids[np.isnan(dt_ids)]
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
original_data.columns = dt_ids

# %%
original_data = original_data.loc[:,~np.isnan(original_data.columns)]

# %%
original_data.columns = original_data.columns.values.astype(int)

# %%
original_data.shape
# Out:
# (4717, 408)

# %%
original_data = original_data.T
original_data = original_data.groupby(original_data.index).mean()
original_data = original_data.T

# %%
original_data.shape
# Out:
# (4717, 273)

# %% [markdown]
# # Load Het data

# %%
original_data2 = pd.read_csv('raw_data/het.ratio_result_nm.pub', sep='\t')

# %%
print('Original data dimensions: %d x %d' % (original_data2.shape))
# Out:
# Original data dimensions: 5984 x 727

# %%
original_data2.head()
# Out:
#               Orf  \
# 0  YAL001C:chr1_1
# 1  YAL002W:chr1_1
# 2  YAL003W:chr1_1
# 3  YAL004W:chr1_1
# 4  YAL005C:chr1_1
#
#    01_04_24_02:benomyl:6.9:um::::15gen:het_04_01_2:old scanner  \
# 0                                          -0.131636
# 1                                           0.037294
# 2                                          -0.293846
# 3                                           0.025424
# 4                                          -0.144465
#
#    01_04_24_03:nocodazole:6.9:um::::15gen:het_04_01_2:old scanner  \
# 0                                          -0.212345
# 1                                          -0.630956
# 2                                          -0.211969
# 3                                          -0.060256
# 4                                          -0.202685
#
#    01_04_24_04:benomyl:13.8:um::::15gen:het_04_01_2:old scanner  \
# 0                                          -0.042362
# 1                                           0.000075
# 2                                          -0.141436
# 3                                           0.078768
# 4                                          -0.334742
#
#    01_05_08_02:nocodazole:6.6:um::::15gen:het_04_01_2:old scanner  \
# 0                                           0.238914
# 1                                          -0.009538
# 2                                           0.028114
# 3                                           0.082459
# 4                                           0.053280
#
#    01_05_11_02:tunicamycin:0.6:um::::5gen:het_04_01_2:old scanner  \
# 0                                           0.050857
# 1                                          -0.286773
# 2                                           0.065929
# 3                                           0.052538
# 4                                           0.150092
#
#    01_05_11_03:tunicamycin:0.15:um::::5gen:het_04_01_2:old scanner  \
# 0                                          -0.229736
# 1                                          -0.065064
# 2                                          -0.085837
# 3                                          -0.041104
# 4                                          -0.093609
#
#    01_05_11_05:5-fluorouracil:19.2:um::::20gen:het_04_01_2:old scanner  \
# 0                                          -0.134586
# 1                                           0.409466
# 2                                          -0.004104
# 3                                          -0.106782
# 4                                          -1.144880
#
#    01_05_15_02:nocodazole:6.6:um::::5gen:het_04_01_2:old scanner  \
# 0                                          -0.005207
# 1                                          -0.038485
# 2                                           0.205367
# 3                                          -0.126677
# 4                                           0.260643
#
#    01_05_15_05:tunicamycin:0.15:um::::15gen:het_04_01_2:old scanner  ...  \
# 0                                           0.141291                 ...
# 1                                          -0.967149                 ...
# 2                                          -0.005246                 ...
# 3                                           0.280637                 ...
# 4                                           2.502130                 ...
#
#    05_05_13_05:thimerosal:125:nm::::20gen:het_06_03:new scanner  \
# 0                                          -0.250066
# 1                                          -0.225882
# 2                                          -0.236016
# 3                                           0.185836
# 4                                           1.057050
#
#    05_05_13_06:bisphenol:8.75:um::::20gen:het_06_03:new scanner  \
# 0                                           0.456222
# 1                                           0.072349
# 2                                          -0.084190
# 3                                           0.033696
# 4                                          -0.040865
#
#    05_05_13_13:motuporamine:7.5:um::::20gen:het_06_03:new scanner  \
# 0                                          -0.140851
# 1                                          -0.357965
# 2                                          -0.410695
# 3                                          -0.139939
# 4                                          -0.228768
#
#    05_05_19_01:PP1:3:um::::20gen:het_06_03:new scanner  \
# 0                                          -0.101573
# 1                                           0.242942
# 2                                           0.195081
# 3                                          -0.028618
# 4                                          -0.177879
#
#    05_05_19_02:PP2:3:um::::20gen:het_06_03:new scanner  \
# 0                                           0.090297
# 1                                          -0.420637
# 2                                           0.048692
# 3                                           0.049193
# 4                                          -0.155201
#
#    05_06_29_11:motuporamine:15:um::::20gen:het_06_03:new scanner  \
# 0                                          -0.903738
# 1                                          -1.169850
# 2                                          -0.366164
# 3                                           0.198638
# 4                                          -0.747556
#
#    05_08_09_01:motuporamine:15:um::::20gen:het_06_03:new scanner  \
# 0                                          -0.242310
# 1                                           0.298605
# 2                                          -0.151471
# 3                                          -0.075491
# 4                                           0.485199
#
#    05_08_09_03:myriocin:0.15:ug/ml::::20gen:het_06_03:new scanner  \
# 0                                          -0.776020
# 1                                          -1.626690
# 2                                          -0.593138
# 3                                          -0.534340
# 4                                          -0.608983
#
#    05_08_09_04:aureobasidin A:0.02:ug/ml::::20gen:het_06_03:new scanner  \
# 0                                          -0.505625
# 1                                          -0.759521
# 2                                          -0.245003
# 3                                          -0.651918
# 4                                          -1.682060
#
#    05_08_12_15:motuporamine:15:um::::20gen:het_06_03:new scanner
# 0                                          -0.307232
# 1                                          -0.811517
# 2                                          -0.164903
# 3                                          -0.103441
# 4                                           2.251360
#
# [5 rows x 727 columns]

# %%
original_data2['orf'] = original_data2['Orf'].apply(lambda x: x.split(':')[0])

# %%
# Eliminate all white spaces & capitalize
original_data2['orf'] = clean_orf(original_data2['orf'])

# %%
# Translate to ORFs 
original_data2['orf'] = translate_sc(original_data2['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data2['orf'])
print(original_data2.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [Orf, 01_04_24_02:benomyl:6.9:um::::15gen:het_04_01_2:old scanner, 01_04_24_03:nocodazole:6.9:um::::15gen:het_04_01_2:old scanner, 01_04_24_04:benomyl:13.8:um::::15gen:het_04_01_2:old scanner, 01_05_08_02:nocodazole:6.6:um::::15gen:het_04_01_2:old scanner, 01_05_11_02:tunicamycin:0.6:um::::5gen:het_04_01_2:old scanner, 01_05_11_03:tunicamycin:0.15:um::::5gen:het_04_01_2:old scanner, 01_05_11_05:5-fluorouracil:19.2:um::::20gen:het_04_01_2:old scanner, 01_05_15_02:nocodazole:6.6:um::::5gen:het_04_01_2:old scanner, 01_05_15_05:tunicamycin:0.15:um::::15gen:het_04_01_2:old scanner, 01_05_15_06:tunicamycin:0.6:um::::15gen:het_04_01_2:old scanner, 01_05_15_07:benomyl:27.6:um::::20gen:het_04_01_2:old scanner, 01_05_16_02:benomyl:3.4:um::::15gen:het_04_01_2:old scanner, 01_05_16_04:benomyl:2.4:um::::5gen:het_04_01_2:old scanner, 01_05_16_05:ketoconazole:11.8:um::::5gen:het_04_01_2:old scanner, 01_05_22_06:hygromycin:0.4:um::::5gen:het_04_01_2:old scanner, 01_05_31_03:37 degrees C::::::5gen:het_04_01_2:old scanner, 01_06_05_06:hygromycin:0.4:um::::20gen:het_04_01_2:old scanner, 01_06_05_09:miconazole:0.2:um::::5gen:het_04_01_2:old scanner, 01_06_06_01:miconazole:0.2:um::::5gen:het_04_01_2:old scanner, 01_06_06_04:23 degrees C::::::5gen:het_04_01_2:old scanner, 01_06_08_05:tunicamycin:0.15:um::::5gen:het_04_01_2:old scanner, 01_06_13_04:37 degrees C::::::20gen:het_04_01_2:old scanner, 01_06_13_06:37 degrees C::::::20gen:het_04_01_2:old scanner, 01_06_14_01:23 degrees C::::::15gen:het_04_01_2:old scanner, 01_06_14_04:YP glycerol::::::5gen:het_04_01_2:old scanner, 01_06_14_06:YP glycerol::::::15gen:het_04_01_2:old scanner, 01_06_19_03:37 degrees C::::::5gen:het_04_01_2:old scanner, 01_06_26_07:23 degrees C::::::5gen:het_04_01_2:old scanner, 01_06_26_09:YP glycerol::::::5gen:het_04_01_2:old scanner, 01_06_28_03:YP glycerol::::::15gen:het_04_01_2:old scanner, 01_06_28_07:miconazole:50:nm::::5gen:het_04_01_2:old scanner, 01_06_28_08:miconazole:50:nm::::15gen:het_04_01_2:old scanner, 01_06_29_02:23 degrees C::::::15gen:het_04_01_2:old scanner, 01_07_17_02:20 degrees C::::::20gen:het_04_01_2:old scanner, 01_07_18_03:clotrimazole:2:um::::20gen:het_04_01_2:old scanner, 01_07_18_04:ketoconazole:1:um::::20gen:het_04_01_2:old scanner, 01_07_18_05:miconazole:50:nm::::20gen:het_04_01_2:old scanner, 01_07_24_06:miconazole:50:nm::::15gen:het_04_01_2:old scanner, 01_07_25_03:37c, 45c::::::5gen:het_04_01_2:old scanner, 01_07_25_04:37 degrees C::::::20gen:het_04_01_2:old scanner, 01_07_31_07:amphotericin B:10:um::::20gen:het_04_01_2:old scanner, 01_07_31_08:nystatin:5:um::::20gen:het_04_01_2:old scanner, 01_08_07_02:hydroxyurea:50000:um::::20gen:het_04_01_2:old scanner, 01_08_14_06:methotrexate:250:um::::20gen:het_04_01_2:old scanner, 01_08_14_07:progesterone:250:um::::20gen:het_04_01_2:old scanner, 01_08_15_01:progesterone:250:um::::20gen:het_04_01_2:old scanner, 01_08_28_05:fenpropimorph:1.65:nm::::15gen:het_04_01_2:old scanner, 01_08_28_06:progesterone:1000:um::::15gen:het_04_01_2:old scanner, 01_08_28_09:cisplatin:125:um::::20gen:het_04_01_2:old scanner, 01_08_28_10:estradiol:1000:um::::20gen:het_04_01_2:old scanner, 01_08_31_01:nocodazole:2:ug/ml::::20gen:het_04_01_2:old scanner, 01_09_13_01:clotrimazole:2:um::::20gen:het_04_01_2:old scanner, 01_09_13_02:methotrexate:125:um::::20gen:het_04_01_2:old scanner, 01_09_13_03:5-fluorouracil:38.5:um::::15gen:het_04_01_2:old scanner, 01_09_14_01:5-fluorouracil:4.8:um::::20gen:het_04_01_2:old scanner, 01_09_14_02:miconazole:100:um::::20gen:het_04_01_2:old scanner, 01_09_14_04:miconazole:25:nm::::20gen:het_04_01_2:old scanner, 01_09_18_01:miconazole:100:um::::20gen:het_04_01_2:old scanner, 01_09_18_02:miconazole:50:nm::::20gen:het_04_01_2:old scanner, 01_09_18_03:miconazole:25:nm::::20gen:het_04_01_2:old scanner, 01_09_19_07:clozapine:125:um::::20gen:het_04_01_2:old scanner, 01_09_19_08:carmustine:31.25:um::::20gen:het_04_01_2:old scanner, 01_09_21_01:hygromycin:0.4:um::::20gen:het_04_01_2:old scanner,  ...
# Index: []
#
# [0 rows x 728 columns]

# %%
original_data2.set_index('orf', inplace=True)

# %%
original_data2.drop(columns=['Orf'], inplace=True)

# %%
original_data2 = original_data2.apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data2 = original_data2.groupby(original_data2.index).mean()

# %%
original_data2.shape
# Out:
# (5887, 726)

# %% [markdown]
# ## Load dataset ids

# %%
dt2 = pd.read_csv('extras/datasets_het.txt', sep='\t')

# %%
dt2.shape
# Out:
# (726, 3)

# %%
dt2.head()
# Out:
#                                                 Name Conditionset  Dataset
# 0  04_02_11_07:1,3-diallylurea:5000:um::::20gen:h...         8406    12265
# 1  04_01_21_05:1,3-diallylurea:10000:um::::20gen:...          752    12215
# 2  03_12_09_06:1,4-dimethylendothall:100:um::::20...          753    12216
# 3  03_12_09_08:1,4-dimethylendothall:500:um::::20...         8408    12267
# 4  03_12_09_07:1,4-dimethylendothall:1000:um::::2...         8407    12266

# %%
dt2['Dataset'] = pd.to_numeric(dt2['Dataset'], errors='coerce')
dt2.head()
# Out:
#                                                 Name Conditionset  Dataset
# 0  04_02_11_07:1,3-diallylurea:5000:um::::20gen:h...         8406    12265
# 1  04_01_21_05:1,3-diallylurea:10000:um::::20gen:...          752    12215
# 2  03_12_09_06:1,4-dimethylendothall:100:um::::20...          753    12216
# 3  03_12_09_08:1,4-dimethylendothall:500:um::::20...         8408    12267
# 4  03_12_09_07:1,4-dimethylendothall:1000:um::::2...         8407    12266

# %%
dt_ids2 = np.array([dt2.loc[dt2['Name']==c,'Dataset'].values[0] for c in original_data2.columns.values])

# %%
original_data2.columns = dt_ids2

# %%
original_data2 = original_data2.loc[:,original_data2.columns>0]

# %%
original_data2.shape
# Out:
# (5887, 721)

# %%
original_data2 = original_data2.T
original_data2 = original_data2.groupby(original_data2.index).mean()
original_data2 = original_data2.T

# %%
original_data2.shape
# Out:
# (5887, 507)

# %% [markdown]
# # Merge

# %%
original_data = original_data.join(original_data2, how='outer')

# %%
original_data.shape
# Out:
# (5888, 780)

# %%
original_data.head()
# Out:
#             778       779       780       781       782       783       784    \
# orf
# YAL001C       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YAL002W -2.271250 -0.885406 -0.423706 -0.529279 -0.703219 -2.498460  0.143344
# YAL003W       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YAL004W -0.424613 -0.151793 -0.061239 -0.206722  0.004740 -0.330591 -0.107357
# YAL005C -1.185780 -0.277463 -0.171724 -0.468994 -0.027950 -0.947262 -0.124123
#
#             785       786       787    ...     12617     12618     12619  \
# orf                                    ...
# YAL001C       NaN       NaN       NaN  ...  0.050857 -0.056812  0.296919
# YAL002W -0.055234 -0.758126  0.217003  ... -0.286773 -0.221440  0.472599
# YAL003W       NaN       NaN       NaN  ...  0.065929 -0.135917 -0.086778
# YAL004W -0.160824 -0.283584 -0.012100  ...  0.052538  0.053578 -0.013720
# YAL005C -0.014067  0.249295 -0.189006  ...  0.150092 -0.170443  0.813991
#
#             12620     12621     12622     12623     12624     12625     12626
# orf
# YAL001C  0.215062 -0.018238  0.031422  0.098524 -0.139622 -0.135583 -0.332011
# YAL002W  0.226105  0.583654 -0.261767  1.021640 -0.538731  0.471850  2.736750
# YAL003W -0.051601  0.155652 -0.363792  0.005760 -0.160483 -0.064899 -0.097966
# YAL004W -0.426523  0.350106 -0.169926  0.198097 -0.196637  0.276150  0.536735
# YAL005C  0.173497  3.035860  0.789079  0.004250 -0.420168 -1.719465 -2.567455
#
# [5 rows x 780 columns]

# %%
# Taking the opposite because the original values are log2(control/treatment)
original_data = -original_data

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = original_data.columns.values
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id     778       779       780       781       782       783    \
# data_type      value     value     value     value     value     value
# orf
# YAL001C          NaN       NaN       NaN       NaN       NaN       NaN
# YAL002W     2.271250  0.885406  0.423706  0.529279  0.703219  2.498460
# YAL003W          NaN       NaN       NaN       NaN       NaN       NaN
# YAL004W     0.424613  0.151793  0.061239  0.206722 -0.004740  0.330591
# YAL005C     1.185780  0.277463  0.171724  0.468994  0.027950  0.947262
#
# dataset_id     784       785       786       787    ...     12617     12618  \
# data_type      value     value     value     value  ...     value     value
# orf                                                 ...
# YAL001C          NaN       NaN       NaN       NaN  ... -0.050857  0.056812
# YAL002W    -0.143344  0.055234  0.758126 -0.217003  ...  0.286773  0.221440
# YAL003W          NaN       NaN       NaN       NaN  ... -0.065929  0.135917
# YAL004W     0.107357  0.160824  0.283584  0.012100  ... -0.052538 -0.053578
# YAL005C     0.124123  0.014067 -0.249295  0.189006  ... -0.150092  0.170443
#
# dataset_id     12619     12620     12621     12622     12623     12624  \
# data_type      value     value     value     value     value     value
# orf
# YAL001C    -0.296919 -0.215062  0.018238 -0.031422 -0.098524  0.139622
# YAL002W    -0.472599 -0.226105 -0.583654  0.261767 -1.021640  0.538731
# YAL003W     0.086778  0.051601 -0.155652  0.363792 -0.005760  0.160483
# YAL004W     0.013720  0.426523 -0.350106  0.169926 -0.198097  0.196637
# YAL005C    -0.813991 -0.173497 -3.035860 -0.789079 -0.004250  0.420168
#
# dataset_id     12625     12626
# data_type      value     value
# orf
# YAL001C     0.135583  0.332011
# YAL002W    -0.471850 -2.736750
# YAL003W     0.064899  0.097966
# YAL004W    -0.276150 -0.536735
# YAL005C     1.719465  2.567455
#
# [5 rows x 780 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 24

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id          778       779       780       781       782       783    \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C       NaN       NaN       NaN       NaN       NaN       NaN
# 2       YAL002W  2.271250  0.885406  0.423706  0.529279  0.703219  2.498460
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W  0.424613  0.151793  0.061239  0.206722 -0.004740  0.330591
# 4       YAL005C  1.185780  0.277463  0.171724  0.468994  0.027950  0.947262
#
# dataset_id          784       785       786       787    ...     12617  \
# data_type           value     value     value     value  ...     value
# gene_id orf                                              ...
# 1       YAL001C       NaN       NaN       NaN       NaN  ... -0.050857
# 2       YAL002W -0.143344  0.055234  0.758126 -0.217003  ...  0.286773
# 3       YAL003W       NaN       NaN       NaN       NaN  ... -0.065929
# 1863    YAL004W  0.107357  0.160824  0.283584  0.012100  ... -0.052538
# 4       YAL005C  0.124123  0.014067 -0.249295  0.189006  ... -0.150092
#
# dataset_id          12618     12619     12620     12621     12622     12623  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C  0.056812 -0.296919 -0.215062  0.018238 -0.031422 -0.098524
# 2       YAL002W  0.221440 -0.472599 -0.226105 -0.583654  0.261767 -1.021640
# 3       YAL003W  0.135917  0.086778  0.051601 -0.155652  0.363792 -0.005760
# 1863    YAL004W -0.053578  0.013720  0.426523 -0.350106  0.169926 -0.198097
# 4       YAL005C  0.170443 -0.813991 -0.173497 -3.035860 -0.789079 -0.004250
#
# dataset_id          12624     12625     12626
# data_type           value     value     value
# gene_id orf
# 1       YAL001C  0.139622  0.135583  0.332011
# 2       YAL002W  0.538731 -0.471850 -2.736750
# 3       YAL003W  0.160483  0.064899  0.097966
# 1863    YAL004W  0.196637 -0.276150 -0.536735
# 4       YAL005C  0.420168  1.719465  2.567455
#
# [5 rows x 780 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
vals = data.values
vals_norm = data_norm.values

vals_norm[np.isnan(vals)] = np.nan

data_norm = pd.DataFrame(index=data_norm.index, columns=data_norm.columns, data=vals_norm)

# %%
data_all = data.join(data_norm)
data_all.head()
# Out:
# dataset_id          778       779       780       781       782       783    \
# data_type           value     value     value     value     value     value
# gene_id orf
# 1       YAL001C       NaN       NaN       NaN       NaN       NaN       NaN
# 2       YAL002W  2.271250  0.885406  0.423706  0.529279  0.703219  2.498460
# 3       YAL003W       NaN       NaN       NaN       NaN       NaN       NaN
# 1863    YAL004W  0.424613  0.151793  0.061239  0.206722 -0.004740  0.330591
# 4       YAL005C  1.185780  0.277463  0.171724  0.468994  0.027950  0.947262
#
# dataset_id          784       785       786       787    ...     12617  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 1       YAL001C       NaN       NaN       NaN       NaN  ...  0.011372
# 2       YAL002W -0.143344  0.055234  0.758126 -0.217003  ...  1.298996
# 3       YAL003W       NaN       NaN       NaN       NaN  ... -0.046107
# 1863    YAL004W  0.107357  0.160824  0.283584  0.012100  ...  0.004963
# 4       YAL005C  0.124123  0.014067 -0.249295  0.189006  ... -0.367082
#
# dataset_id          12618     12619     12620      12621     12622     12623  \
# data_type          valuez    valuez    valuez     valuez    valuez    valuez
# gene_id orf
# 1       YAL001C  0.298955 -0.688466 -0.607084  -0.132349 -0.084872 -0.355709
# 2       YAL002W  0.867487 -1.153891 -0.649131  -2.165734  0.896415 -3.371057
# 3       YAL003W  0.572140  0.328054  0.408256  -0.719806  1.237887 -0.052696
# 1863    YAL004W -0.082267  0.134503  1.835800  -1.376734  0.589028 -0.680963
# 4       YAL005C  0.691373 -2.058333 -0.448822 -10.450075 -2.620708 -0.047764
#
# dataset_id          12624     12625     12626
# data_type          valuez    valuez    valuez
# gene_id orf
# 1       YAL001C  0.342990  0.222588  0.584895
# 2       YAL002W  1.421395 -1.329920 -5.284732
# 3       YAL003W  0.399357  0.041930  0.137238
# 1863    YAL004W  0.497046 -0.829740 -1.076756
# 4       YAL005C  1.101034  4.270754  4.860637
#
# [5 rows x 1560 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
# from IO.save_data_to_db3 import *

# %%
# save_data_to_db(data_all, paper_pmid)
