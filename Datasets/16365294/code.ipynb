# %%
import numpy as np
import pandas as pd

import sys
import re

from os.path import expanduser
sys.path.append(expanduser('~') + '/Lab/Utils/Python/')

from Conversions.translate import *
from Strings.is_a import *
from Math.normalize import z_transform_mode

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 16365294
paper_name = 'ohya_morishita_2005'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['pmid', 'name'])

# %%
datasets.set_index('pmid', inplace=True)

# %%
path_to_genes = '../../Private-Utils/datasets_gene2.txt'
path_to_consensus_tested = '../../Private-Utils/yp_2020-09-01_orfs.txt'

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_csv('raw_data/mutant_analysis_2011_10_20.tab', sep='\t')

# %%
original_data.head()
# Out:
#       name    A101_A  A101_A1B    A101_C  A102_A1B    A102_C  A103_A1B  \
# 0  YAL002W  0.241397  0.203596  0.265229  0.674227  0.634847  0.047427
# 1  YAL004W  0.176769  0.171474  0.215702  0.698654  0.651637  0.042315
# 2  YAL005C  0.419048  0.380287  0.386104  0.447943  0.531675  0.092326
# 3  YAL007C  0.253365  0.220201  0.241407  0.584807  0.594684  0.041358
# 4  YAL008W  0.198676  0.188937  0.213454  0.705330  0.666906  0.035833
#
#      A103_C  A104_A1B    A104_C  ...  DCV192_C  DCV193_A1B  DCV193_C  \
# 0  0.038288  0.147991  0.114015  ...  0.242811    0.265602  0.223247
# 1  0.050097  0.127242  0.130586  ...  0.334429    0.320537  0.326231
# 2  0.073756  0.092021  0.089312  ...  0.414805    0.424925  0.401604
# 3  0.039212  0.113065  0.100998  ...  0.429069    0.605917  0.414244
# 4  0.026512  0.131503  0.120423  ...  0.314824    0.358865  0.298404
#
#    DCV194_A  DCV194_C  DCV195_C  DCV196_A1B  DCV196_C  DCV197_C  DCV198_C
# 0  0.100176  0.102437  0.136084    0.086192  0.112866  0.276915  0.347655
# 1  0.081514  0.081050  0.097439    0.075716  0.094022  0.186023  0.238855
# 2  0.098086  0.104103  0.113818    0.083131  0.088795  0.221838  0.314937
# 3  0.092948  0.126720  0.126254    0.107495  0.126775  0.228581  0.330954
# 4  0.107541  0.144381  0.161155    0.100240  0.140840  0.240061  0.318372
#
# [5 rows x 502 columns]

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4718 x 502

# %%
original_data['name'] = original_data['name'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['name'] = clean_orf(original_data['name'])

# %%
# Translate to ORFs 
original_data['name'] = translate_sc(original_data['name'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['name'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [name, A101_A, A101_A1B, A101_C, A102_A1B, A102_C, A103_A1B, A103_C, A104_A1B, A104_C, A105, A105_A, A106, A106_A, A107, A107_A1B, A107_C, A108, A108_A1B, A108_C, A109, A109_A1B, A109_C, A110, A110_A1B, A110_C, A111, A112, A112_A1B, A112_C, A113, A113_A, A113_A1B, A113_C, A114, A115, A116, A117, A118, A119, A120_A, A120_A1B, A120_C, A121_A, A121_A1B, A121_C, A122_A, A122_A1B, A122_C, A123_A, A123_A1B, A123_C, A7-1_A, A7-1_A1B, A7-1_C, A7-2_A1B, A7-2_C, A8-1_A, A8-1_A1B, A8-1_C, A8-2_A1B, A8-2_C, A9_A1B, A9_C, ACV101_A, ACV101_A1B, ACV101_C, ACV102_A1B, ACV102_C, ACV103_A1B, ACV103_C, ACV104_A1B, ACV104_C, ACV120_A, ACV120_A1B, ACV120_C, ACV121_A, ACV121_A1B, ACV121_C, ACV122_A, ACV122_A1B, ACV122_C, ACV123_A, ACV123_A1B, ACV123_C, ACV7-1_A, ACV7-1_A1B, ACV7-1_C, ACV7-2_A1B, ACV7-2_C, ACV8-1_A, ACV8-1_A1B, ACV8-1_C, ACV8-2_A1B, ACV8-2_C, ACV9_A1B, ACV9_C, C101_A1B, C101_C, C102_A1B, ...]
# Index: []
#
# [0 rows x 502 columns]

# %%
original_data.set_index('name', inplace=True)
original_data.index.name='orf'

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4715, 501)

# %% [markdown]
# # Process parameters

# %%
datasets.head()
# Out:
#                                                    name
# pmid
# 5405  hap a | Length of the long axis of the nucleus...
# 5406  hap a | Length of the long axis of the nucleus...
# 5407  hap a | Length of the short axis of the cell i...
# 5408  hap a | Length of the short axis of the daugth...
# 5409  hap a | Length of the short axis of the daugth...

# %%
datasets['phenotype_name'] = ''
datasets['phenotype_id'] = ''
for d in datasets.index.values:
    t = datasets.loc[d,'name'].split('|')[1]
    matches = re.findall('\(([A-Z0-9_\-]*?)\)', t)
    
    datasets.loc[d,'phenotype_name'] = t
    datasets.loc[d,'phenotype_id'] = matches[0]

# %%
# Exclude the CV parameters and the ones that are not easily interpretable
original_data = original_data.reindex(columns=datasets['phenotype_id'].values)

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id       5405       5406       5407       5408       5409       5410  \
# data_type       value      value      value      value      value      value
# orf
# YAL002W     10.760599  12.093151  28.587365  18.875788  27.630382  31.276813
# YAL004W     10.198289  11.566228  27.898675  17.140943  25.662899  29.756041
# YAL005C      9.392640  10.667163  24.999431  16.894838  25.123329  28.395172
# YAL007C      9.652285  11.673625  28.042097  19.529432  26.086144  30.465722
# YAL008W      9.183315  11.184889  28.679312  18.826658  26.075371  31.173199
#
# dataset_id       5411        5412        5413        5414  ...      5647  \
# data_type       value       value       value       value  ...     value
# orf                                                        ...
# YAL002W     31.189958  141.775000  144.410448  139.309278  ...  0.291139
# YAL004W     29.990882  170.021739  184.736111  189.127273  ...  0.295455
# YAL005C     27.862895  113.470588  126.586466  124.925000  ...  0.339056
# YAL007C     29.918406   94.535714   92.268966  116.564103  ...  0.233108
# YAL008W     30.523229  108.119658  112.297101  135.786667  ...  0.292237
#
# dataset_id       5648       5649       5650       5651       5652       5653  \
# data_type       value      value      value      value      value      value
# orf
# YAL002W     33.279666  15.705237  27.323638  36.134226  35.849083  11.206696
# YAL004W     34.080315  15.140221  25.878160  36.172433  36.510306  11.362220
# YAL005C     31.042787  14.454373  24.727850  34.522438  34.838594  10.628542
# YAL007C     34.102268  17.926000  26.965144  36.892710  37.060877  11.165609
# YAL008W     34.633543  16.949242  26.381888  37.790210  37.355775  10.533115
#
# dataset_id       5654        5655        5656
# data_type       value       value       value
# orf
# YAL002W     13.043053  107.620552  104.793230
# YAL004W     12.338489  130.392640  118.121328
# YAL005C     13.590983   91.653600   82.918831
# YAL007C     14.114610   67.751113   68.213550
# YAL008W     13.599617   84.127483   82.816581
#
# [5 rows x 252 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=original_data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 20

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

# %%
data.head()
# Out:
# dataset_id            5405       5406       5407       5408       5409  \
# data_type            value      value      value      value      value
# gene_id orf
# 2       YAL002W  10.760599  12.093151  28.587365  18.875788  27.630382
# 1863    YAL004W  10.198289  11.566228  27.898675  17.140943  25.662899
# 4       YAL005C   9.392640  10.667163  24.999431  16.894838  25.123329
# 5       YAL007C   9.652285  11.673625  28.042097  19.529432  26.086144
# 6       YAL008W   9.183315  11.184889  28.679312  18.826658  26.075371
#
# dataset_id            5410       5411        5412        5413        5414  \
# data_type            value      value       value       value       value
# gene_id orf
# 2       YAL002W  31.276813  31.189958  141.775000  144.410448  139.309278
# 1863    YAL004W  29.756041  29.990882  170.021739  184.736111  189.127273
# 4       YAL005C  28.395172  27.862895  113.470588  126.586466  124.925000
# 5       YAL007C  30.465722  29.918406   94.535714   92.268966  116.564103
# 6       YAL008W  31.173199  30.523229  108.119658  112.297101  135.786667
#
# dataset_id       ...      5647       5648       5649       5650       5651  \
# data_type        ...     value      value      value      value      value
# gene_id orf      ...
# 2       YAL002W  ...  0.291139  33.279666  15.705237  27.323638  36.134226
# 1863    YAL004W  ...  0.295455  34.080315  15.140221  25.878160  36.172433
# 4       YAL005C  ...  0.339056  31.042787  14.454373  24.727850  34.522438
# 5       YAL007C  ...  0.233108  34.102268  17.926000  26.965144  36.892710
# 6       YAL008W  ...  0.292237  34.633543  16.949242  26.381888  37.790210
#
# dataset_id            5652       5653       5654        5655        5656
# data_type            value      value      value       value       value
# gene_id orf
# 2       YAL002W  35.849083  11.206696  13.043053  107.620552  104.793230
# 1863    YAL004W  36.510306  11.362220  12.338489  130.392640  118.121328
# 4       YAL005C  34.838594  10.628542  13.590983   91.653600   82.918831
# 5       YAL007C  37.060877  11.165609  14.114610   67.751113   68.213550
# 6       YAL008W  37.355775  10.533115  13.599617   84.127483   82.816581
#
# [5 rows x 252 columns]

# %% [markdown]
# # Normalize

# %%
def normalize_phenotypic_scores(df, has_tested=False):
    
    if not has_tested:
        
        genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
        genes = genes.reset_index().set_index('systematic_name', drop=False)
        
        yp_orfs = pd.read_csv(path_to_consensus_tested, header=None)
        yp_orfs = yp_orfs[1].values
        consensus_tested = [tuple(genes.loc[orf,['id','systematic_name']]) for orf in yp_orfs]
        
        df_index = [tuple(x) for x in df.index]
        
        consensus_tested = list(set(consensus_tested + df_index))
        
        df = df.reindex(index=consensus_tested, fill_value=0)
        
    df_norm = z_transform_mode(data)
    
    return df_norm

# %%
data_norm = normalize_phenotypic_scores(data)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan

# %%
data_all = data.join(data_norm)

# %%
data_all.head()
# Out:
# dataset_id            5405       5406       5407       5408       5409  \
# data_type            value      value      value      value      value
# gene_id orf
# 2       YAL002W  10.760599  12.093151  28.587365  18.875788  27.630382
# 1863    YAL004W  10.198289  11.566228  27.898675  17.140943  25.662899
# 4       YAL005C   9.392640  10.667163  24.999431  16.894838  25.123329
# 5       YAL007C   9.652285  11.673625  28.042097  19.529432  26.086144
# 6       YAL008W   9.183315  11.184889  28.679312  18.826658  26.075371
#
# dataset_id            5410       5411        5412        5413        5414  \
# data_type            value      value       value       value       value
# gene_id orf
# 2       YAL002W  31.276813  31.189958  141.775000  144.410448  139.309278
# 1863    YAL004W  29.756041  29.990882  170.021739  184.736111  189.127273
# 4       YAL005C  28.395172  27.862895  113.470588  126.586466  124.925000
# 5       YAL007C  30.465722  29.918406   94.535714   92.268966  116.564103
# 6       YAL008W  31.173199  30.523229  108.119658  112.297101  135.786667
#
# dataset_id       ...      5647      5648      5649      5650      5651  \
# data_type        ...    valuez    valuez    valuez    valuez    valuez
# gene_id orf      ...
# 2       YAL002W  ... -0.371945 -0.070331 -0.159067  0.594541  0.064916
# 1863    YAL004W  ... -0.297492  0.278901 -0.540030 -0.148470  0.081119
# 4       YAL005C  ...  0.454767 -1.046025 -1.002466 -0.739757 -0.618641
# 5       YAL007C  ... -1.373165  0.288476  1.338291  0.410266  0.386588
# 6       YAL008W  ... -0.352997  0.520211  0.679708  0.110458  0.767216
#
# dataset_id           5652      5653      5654      5655      5656
# data_type          valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W -0.174340  0.231727  0.050617  0.577823  0.969929
# 1863    YAL004W  0.108348  0.370839 -0.392437  1.723406  1.843186
# 4       YAL005C -0.606348 -0.285411  0.395175 -0.225418 -0.463282
# 5       YAL007C  0.343731  0.194977  0.724450 -1.427867 -1.426772
# 6       YAL008W  0.469807 -0.370767  0.400604 -0.604030 -0.469982
#
# [5 rows x 504 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs('value', level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 16365294...
#   0%|          | 0/252 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 252/252 [28:29<00:00,  6.78s/it]
