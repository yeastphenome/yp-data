# %%
# %run ../yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 33958448
paper_name = 'costanzo_andrews_2021'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/Costanzo_et_al_Data_File_1_Conditions_Strains_Fitness.xlsx', 
                              sheet_name='Diff. Mutant fitness_Conditions')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4429 x 19

# %%
original_data.head()
# Out:
#   Systematic Name Gene Name Allele (Essential genes only) Strain ID  \
# 0         YAL001C      TFC3                    tfc3-g349e    tsa508
# 1         YAL002W      VPS8                           NaN     dma23
# 2         YAL004W       NaN                           NaN     dma22
# 3         YAL005C      SSA1                           NaN     dma21
# 4         YAL007C      ERP2                           NaN     dma20
#
#   on Diagnostic Array  Actinomycin D  Benomyl  Boretzeomib  Caspofungin   \
# 0                 NaN         0.0050   0.1380      -0.0220       -0.0180
# 1                 NaN        -0.4890  -0.1980      -0.1150       -0.0360
# 2                 NaN        -0.0245  -0.0525      -0.0145       -0.0045
# 3                 NaN        -0.0310   0.0100      -0.0150        0.0260
# 4                 NaN        -0.0315   0.0295       0.0215       -0.0505
#
#    Concanmycin A  Cycloheximide  Fluconazole  Galactose  Geldanamycin    MMS   \
# 0         0.0280        -0.0080       0.0510     0.0400       -0.0250  0.0290
# 1        -0.1320        -0.0450      -0.0270    -0.0940       -0.0670 -0.0520
# 2        -0.0535        -0.0275      -0.0145    -0.0225        0.0195  0.0025
# 3        -0.0460        -0.0020       0.0750    -0.0250       -0.0040 -0.0130
# 4         0.0585         0.0205       0.0215     0.0145        0.0335 -0.0435
#
#    Monensin  Rapamycin  Sorbitol  Tunicamycin
# 0   -0.0370    -0.0020   -0.0370      -0.0240
# 1   -0.0330    -0.2965   -0.1115      -0.0850
# 2   -0.0085     0.1730    0.0870      -0.0005
# 3   -0.0230     0.2015    0.1265       0.0430
# 4   -0.0085     0.0835   -0.0265      -0.0105

# %%
# Only keep non-essential genes
original_data = original_data.loc[original_data['Strain ID'].str.startswith('dma'),:].copy()

# %%
original_data['orf'] = original_data['Systematic Name'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
#             Systematic Name Gene Name Allele (Essential genes only) Strain ID  \
# index_input
# 3847                YOL153C       NaN                           NaN   dma5334
# 3882                YOR031W      CRS5                           NaN   dma4461
#
#             on Diagnostic Array  Actinomycin D  Benomyl  Boretzeomib  \
# index_input
# 3847                        NaN        -0.0180  -0.0200       0.0070
# 3882                        NaN         0.0035   0.0445      -0.0165
#
#              Caspofungin   Concanmycin A  Cycloheximide  Fluconazole  \
# index_input
# 3847               0.0350        -0.0120        -0.0340      -0.0130
# 3882               0.0225        -0.0095         0.0215       0.0235
#
#              Galactose  Geldanamycin    MMS   Monensin  Rapamycin  Sorbitol  \
# index_input
# 3847           -0.0650       -0.0160 -0.0450   -0.0140    -0.0180    0.0030
# 3882           -0.0005        0.0115 -0.0235   -0.0075     0.1055    0.0255
#
#              Tunicamycin  orf
# index_input
# 3847             -0.0080  NaN
# 3882             -0.0245  NaN

# %%
original_data = original_data.loc[t,:]

# %%
original_data.set_index('orf', inplace=True)

# %%
data_cols = original_data.columns.values[5:]
original_data = original_data[data_cols].copy()

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (3627, 14)

# %%
data_cols
# Out:
# array(['Actinomycin D', 'Benomyl', 'Boretzeomib', 'Caspofungin ',
#        'Concanmycin A', 'Cycloheximide', 'Fluconazole', 'Galactose',
#        'Geldanamycin', 'MMS ', 'Monensin', 'Rapamycin', 'Sorbitol',
#        'Tunicamycin'], dtype=object)

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = np.arange(21889,21903)

# %%
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id   21889   21890   21891   21892   21893   21894   21895   21896  \
# data_type    value   value   value   value   value   value   value   value
# orf
# YAL002W    -0.4890 -0.1980 -0.1150 -0.0360 -0.1320 -0.0450 -0.0270 -0.0940
# YAL004W    -0.0245 -0.0525 -0.0145 -0.0045 -0.0535 -0.0275 -0.0145 -0.0225
# YAL005C    -0.0310  0.0100 -0.0150  0.0260 -0.0460 -0.0020  0.0750 -0.0250
# YAL007C    -0.0315  0.0295  0.0215 -0.0505  0.0585  0.0205  0.0215  0.0145
# YAL008W     0.0195 -0.0135 -0.0275  0.0315  0.0315  0.0335 -0.0515  0.0255
#
# dataset_id   21897   21898   21899   21900   21901   21902
# data_type    value   value   value   value   value   value
# orf
# YAL002W    -0.0670 -0.0520 -0.0330 -0.2965 -0.1115 -0.0850
# YAL004W     0.0195  0.0025 -0.0085  0.1730  0.0870 -0.0005
# YAL005C    -0.0040 -0.0130 -0.0230  0.2015  0.1265  0.0430
# YAL007C     0.0335 -0.0435 -0.0085  0.0835 -0.0265 -0.0105
# YAL008W     0.0555  0.0005  0.0225  0.0410 -0.0280 -0.0225

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 13

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id        21889   21890   21891   21892   21893   21894   21895  \
# data_type         value   value   value   value   value   value   value
# gene_id orf
# 2       YAL002W -0.4890 -0.1980 -0.1150 -0.0360 -0.1320 -0.0450 -0.0270
# 1863    YAL004W -0.0245 -0.0525 -0.0145 -0.0045 -0.0535 -0.0275 -0.0145
# 4       YAL005C -0.0310  0.0100 -0.0150  0.0260 -0.0460 -0.0020  0.0750
# 5       YAL007C -0.0315  0.0295  0.0215 -0.0505  0.0585  0.0205  0.0215
# 6       YAL008W  0.0195 -0.0135 -0.0275  0.0315  0.0315  0.0335 -0.0515
#
# dataset_id        21896   21897   21898   21899   21900   21901   21902
# data_type         value   value   value   value   value   value   value
# gene_id orf
# 2       YAL002W -0.0940 -0.0670 -0.0520 -0.0330 -0.2965 -0.1115 -0.0850
# 1863    YAL004W -0.0225  0.0195  0.0025 -0.0085  0.1730  0.0870 -0.0005
# 4       YAL005C -0.0250 -0.0040 -0.0130 -0.0230  0.2015  0.1265  0.0430
# 5       YAL007C  0.0145  0.0335 -0.0435 -0.0085  0.0835 -0.0265 -0.0105
# 6       YAL008W  0.0255  0.0555  0.0005  0.0225  0.0410 -0.0280 -0.0225

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id        21889   21890   21891   21892   21893   21894   21895  \
# data_type         value   value   value   value   value   value   value
# gene_id orf
# 2       YAL002W -0.4890 -0.1980 -0.1150 -0.0360 -0.1320 -0.0450 -0.0270
# 1863    YAL004W -0.0245 -0.0525 -0.0145 -0.0045 -0.0535 -0.0275 -0.0145
# 4       YAL005C -0.0310  0.0100 -0.0150  0.0260 -0.0460 -0.0020  0.0750
# 5       YAL007C -0.0315  0.0295  0.0215 -0.0505  0.0585  0.0205  0.0215
# 6       YAL008W  0.0195 -0.0135 -0.0275  0.0315  0.0315  0.0335 -0.0515
#
# dataset_id        21896   21897   21898  ...     21893     21894     21895  \
# data_type         value   value   value  ...    valuez    valuez    valuez
# gene_id orf                              ...
# 2       YAL002W -0.0940 -0.0670 -0.0520  ... -1.480624 -1.062316 -0.423861
# 1863    YAL004W -0.0225  0.0195  0.0025  ... -0.379781 -0.600236 -0.160874
# 4       YAL005C -0.0250 -0.0040 -0.0130  ... -0.274605  0.073079  1.722116
# 5       YAL007C  0.0145  0.0335 -0.0435  ...  1.190849  0.667181  0.596530
# 6       YAL008W  0.0255  0.0555  0.0005  ...  0.812215  1.010440 -0.939317
#
# dataset_id          21896     21897     21898     21899     21900     21901  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W -1.100675 -1.253285 -0.899562 -0.877244 -3.534203 -1.905278
# 1863    YAL004W -0.204370  0.432885  0.263113 -0.307792  1.795568  1.361305
# 4       YAL005C -0.235710 -0.025207 -0.067556 -0.644815  2.119100  2.011330
# 5       YAL007C  0.259452  0.705791 -0.718227 -0.307792  0.779562 -0.506489
# 6       YAL008W  0.397345  1.134643  0.220446  0.412738  0.297102 -0.531174
#
# dataset_id          21902
# data_type          valuez
# gene_id orf
# 2       YAL002W -1.342088
# 1863    YAL004W  0.045876
# 4       YAL005C  0.760389
# 5       YAL007C -0.118381
# 6       YAL008W -0.315488
#
# [5 rows x 28 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Deleting all datasets for PMID 33958448...
# Inserting the new data...
# 100%|██████████| 14/14 [01:10<00:00,  5.04s/it]
# Updating the data_modified_on field...
