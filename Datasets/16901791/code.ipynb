# %%
# %run ../yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 16901791
paper_name = 'parsons_boone_2006'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/mmc8.xlsx', sheet_name='Supplementary Table 7', skiprows=2)

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4111 x 83

# %%
original_data.head()
# Out:
#        ORF Sulfometuron methyl       MMS  Clotrimazole   Benomyl  Plumbagin   \
# 0  YOL023W               0.0334  0.561025     -0.209075   0.64975    0.26125
# 1  YGR068C               0.0886 -0.250225     -0.049075   -0.1688    -0.3209
# 2  YOR324C            -0.031225  0.382675       -0.1845  0.023675    0.11255
# 3  YEL038W             0.234975 -0.190575     -0.206775  0.437125  -0.010175
# 4  YBR053C              0.20735   -0.3209     -0.126925  0.014375    0.01585
#
#   Hydroxyurea   Artemisinin  Amantadine hydrochloride   4-Hydroxytamoxifen   \
# 0     0.252775      0.523600                  -0.04285             0.156600
# 1      0.16505      0.104325                  -0.49075             0.003600
# 2    -0.129925      0.268600                 -0.146675            -0.182100
# 3      0.00145     -0.020550                     0.379            -0.045725
# 4    -0.276225     -0.307075                 -0.230925             0.140800
#
#    ... Cytochalasin A  CG4-Theopalauamide   Caspofungin  Camptothecin   \
# 0  ...       -0.025950            0.226875      -0.25875       -0.4545
# 1  ...       -0.165550            0.102475     -0.491225       0.15085
# 2  ...       -0.213175           -0.643625     -0.037625        0.1427
# 3  ...       -0.198550              0.3535      0.092125      0.024125
# 4  ...        0.259825            0.020025       -0.3327      0.086075
#
#   Basiliskamide  192A4-Stichloroside  Papuamide B  Agelasine E  Fluconazole   \
# 0         0.3404            -0.794250      -0.0792     0.193275     0.250175
# 1      -0.165825            -0.434950    -0.382275      0.01865       0.1371
# 2       0.403825            -0.831175    -0.139625      0.08035    -0.330575
# 3       0.331275            -0.223125      -0.2153     -0.16785     0.005375
# 4         0.3147            -0.273300      -0.0665     0.068525     0.168425
#
#   Geldanamycin
# 0     -0.301775
# 1      -0.13895
# 2     -0.099125
# 3      0.166925
# 4     -0.126825
#
# [5 rows x 83 columns]

# %%
original_data['orf'] = original_data['ORF'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [ORF, Sulfometuron methyl , MMS , Clotrimazole , Benomyl , Plumbagin , Hydroxyurea , Artemisinin , Amantadine hydrochloride , 4-Hydroxytamoxifen , Usnic acid , Sodium Azide , Nystatin , Neomycin sulfate , Caffeine , Menthol , Verrucarin , Valinomycin , Trifluoroperazine , Tamoxifen , Raloxifene , Pentamidine , Nigericin , LY-294,002 , Latrunculin B , Hydroxyethilhidrazine , Hydrogen peroxide , Hoechst , Harmine , Haloperidol , Fenpropimorph , Emetine , Dyclonine , Doxycycline , Cyclopiazonic acid , Clomiphene , Cisplatin , Chlorpromazine , Cerulenin , Calcium ionophore , Anisomycin , Amphotericin , Amiodarone , Alamethicin , Actinomycin , Abietic acid , Wortmannin , Staurosporine , Conine , Parthenolide , Radicicol , Mitomycin C , Trichostatin A , FK506 , Brefeldin A , U73122 , Tunicamycin , Thialysine , Rapamycin , Phenylarsine oxide , Phenantroline , Oligomycin , Nocodazole , Hygromycin B , Extract 95-57 , Extract 6592 , Extract 00-89 , Extract 00-303C , Extract 00-243 , Extract 00-192 , Extract 00-132 , Emodin , Desipramine , Cytochalasin A , CG4-Theopalauamide , Caspofungin , Camptothecin , Basiliskamide , 192A4-Stichloroside , Papuamide B , Agelasine E , Fluconazole , Geldanamycin , orf]
# Index: []
#
# [0 rows x 84 columns]

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data.drop(columns=['ORF'], inplace=True)

# %%
original_data = -original_data.apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4110, 82)

# %% [markdown]
# # Load dataset ids

# %%
mp = pd.read_csv('extras/phenotype_dataset.txt', sep='\t', header=None)

# %%
mp.head()
# Out:
#                       0    1
# 0  192A4-Stichloroside   676
# 1   4-Hydroxytamoxifen   613
# 2         Abietic acid   604
# 3          Actinomycin   614
# 4          Agelasine E   615

# %%
mp.set_index(0, inplace=True)

# %%
mp = mp.reindex(original_data.columns.values)

# %%
dataset_ids = mp[1].values

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id     677       659      632      623      670      655       621  \
# data_type    value     value    value    value    value    value     value
# orf
# YAL005C     0.1564 -0.451800  0.38010 -1.01585  0.28765 -0.26370 -0.383000
# YAL007C     0.0367  0.104650  0.22980  0.09095 -0.00615 -0.08840 -0.390500
# YAL008W    -0.0371 -0.287350 -0.09735 -0.21750  0.08915 -0.02020  0.001850
# YAL010C     0.4116  1.026250  0.27870 -1.10720  0.45070  0.25440 -0.518400
# YAL012W    -0.1209  0.164675  0.04165  0.21850 -0.04660  0.01295 -0.405075
#
# dataset_id      617       613      608  ...       634      679      627  \
# data_type     value     value    value  ...     value    value    value
# orf                                     ...
# YAL005C    -0.03210  0.151450 -0.02300  ...  0.308800 -0.11330 -0.07190
# YAL007C    -0.24890  0.157050  0.01090  ... -0.192500  0.30010 -0.42645
# YAL008W    -0.39615  0.169300  0.15375  ... -0.255150  0.30105 -0.21525
# YAL010C    -2.06870 -0.520500  0.68820  ... -0.130050 -1.37650  0.60970
# YAL012W     0.64905  0.311125 -0.00325  ... -1.112025 -0.78875 -0.00440
#
# dataset_id      610       622       676       666      615      649       650
# data_type     value     value     value     value    value    value     value
# orf
# YAL005C     0.02400  0.160200  0.456950 -0.276400 -0.35690  0.09570  0.168450
# YAL007C    -0.23630  0.043150 -0.640700  0.258050  0.05405 -0.73465  0.133000
# YAL008W    -0.03060 -0.751600 -0.010100  0.281850  0.13060 -0.33465  0.186400
# YAL010C     0.66415 -0.436300 -1.443400 -1.080600 -0.21725  0.40295  0.539900
# YAL012W     0.34200  0.068675 -0.799625  0.755075 -0.14715  0.10460 -0.382225
#
# [5 rows x 82 columns]

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 14

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id          677       659      632      623      670      655  \
# data_type         value     value    value    value    value    value
# gene_id orf
# 4       YAL005C  0.1564 -0.451800  0.38010 -1.01585  0.28765 -0.26370
# 5       YAL007C  0.0367  0.104650  0.22980  0.09095 -0.00615 -0.08840
# 6       YAL008W -0.0371 -0.287350 -0.09735 -0.21750  0.08915 -0.02020
# 8       YAL010C  0.4116  1.026250  0.27870 -1.10720  0.45070  0.25440
# 10      YAL012W -0.1209  0.164675  0.04165  0.21850 -0.04660  0.01295
#
# dataset_id            621      617       613      608  ...       634      679  \
# data_type           value    value     value    value  ...     value    value
# gene_id orf                                            ...
# 4       YAL005C -0.383000 -0.03210  0.151450 -0.02300  ...  0.308800 -0.11330
# 5       YAL007C -0.390500 -0.24890  0.157050  0.01090  ... -0.192500  0.30010
# 6       YAL008W  0.001850 -0.39615  0.169300  0.15375  ... -0.255150  0.30105
# 8       YAL010C -0.518400 -2.06870 -0.520500  0.68820  ... -0.130050 -1.37650
# 10      YAL012W -0.405075  0.64905  0.311125 -0.00325  ... -1.112025 -0.78875
#
# dataset_id           627      610       622       676       666      615  \
# data_type          value    value     value     value     value    value
# gene_id orf
# 4       YAL005C -0.07190  0.02400  0.160200  0.456950 -0.276400 -0.35690
# 5       YAL007C -0.42645 -0.23630  0.043150 -0.640700  0.258050  0.05405
# 6       YAL008W -0.21525 -0.03060 -0.751600 -0.010100  0.281850  0.13060
# 8       YAL010C  0.60970  0.66415 -0.436300 -1.443400 -1.080600 -0.21725
# 10      YAL012W -0.00440  0.34200  0.068675 -0.799625  0.755075 -0.14715
#
# dataset_id           649       650
# data_type          value     value
# gene_id orf
# 4       YAL005C  0.09570  0.168450
# 5       YAL007C -0.73465  0.133000
# 6       YAL008W -0.33465  0.186400
# 8       YAL010C  0.40295  0.539900
# 10      YAL012W  0.10460 -0.382225
#
# [5 rows x 82 columns]

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id          677       659      632      623      670      655  \
# data_type         value     value    value    value    value    value
# gene_id orf
# 4       YAL005C  0.1564 -0.451800  0.38010 -1.01585  0.28765 -0.26370
# 5       YAL007C  0.0367  0.104650  0.22980  0.09095 -0.00615 -0.08840
# 6       YAL008W -0.0371 -0.287350 -0.09735 -0.21750  0.08915 -0.02020
# 8       YAL010C  0.4116  1.026250  0.27870 -1.10720  0.45070  0.25440
# 10      YAL012W -0.1209  0.164675  0.04165  0.21850 -0.04660  0.01295
#
# dataset_id            621      617       613      608  ...       634  \
# data_type           value    value     value    value  ...    valuez
# gene_id orf                                            ...
# 4       YAL005C -0.383000 -0.03210  0.151450 -0.02300  ...  0.866856
# 5       YAL007C -0.390500 -0.24890  0.157050  0.01090  ... -0.571408
# 6       YAL008W  0.001850 -0.39615  0.169300  0.15375  ... -0.751155
# 8       YAL010C -0.518400 -2.06870 -0.520500  0.68820  ... -0.392235
# 10      YAL012W -0.405075  0.64905  0.311125 -0.00325  ... -3.209588
#
# dataset_id            679       627       610       622       676       666  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 4       YAL005C -0.335959 -0.149372 -0.000288  0.425894  0.700529 -0.551552
# 5       YAL007C  0.411684 -0.671606 -0.546270  0.135151 -0.959085  0.237283
# 6       YAL008W  0.413402 -0.360519 -0.114812 -1.838948 -0.005636  0.272411
# 8       YAL010C -2.620486  0.854591  1.342435 -1.055767 -2.172743 -1.738530
# 10      YAL012W -1.557526 -0.049948  0.666721  0.198553 -1.199374  0.970879
#
# dataset_id            615       649       650
# data_type          valuez    valuez    valuez
# gene_id orf
# 4       YAL005C -1.355191  0.154105  0.243814
# 5       YAL007C  0.185113 -1.562215  0.172548
# 6       YAL008W  0.472035 -0.735422  0.279898
# 8       YAL010C -0.831761  0.789186  0.990540
# 10      YAL012W -0.569015  0.172501 -0.863209
#
# [5 rows x 164 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 16901791...
#   0%|          | 0/82 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 82/82 [08:03<00:00,  5.90s/it]
# Updating the data_modified_on field...
