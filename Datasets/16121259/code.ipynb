# %%
# %run ../../Utils/yp_utils.py

# %% [markdown]
# # Initial setup

# %%
paper_pmid = 16121259
paper_name = 'lee_giaever_2005'

# %%
datasets = pd.read_csv('extras/YeastPhenome_' + str(paper_pmid) + '_datasets_list.txt', sep='\t', header=None, names=['dataset_id', 'name'])

# %%
datasets.set_index('dataset_id', inplace=True)

# %% [markdown]
# # Load & process the data

# %%
original_data = pd.read_excel('raw_data/pgen.0010024.sd001.xlsx', sheet_name='OrfGeneData')

# %%
print('Original data dimensions: %d x %d' % (original_data.shape))
# Out:
# Original data dimensions: 4758 x 115

# %%
original_data.head()
# Out:
#        ORF   Batch     Gene                          GO_process  \
# 0  YAL002W  chr1_1     VPS8  late endosome to vacuole transport
# 1  YAL004W  chr1_1  YAL004W                                 NaN
# 2  YAL005C  chr1_1     SSA1                    protein folding*
# 3  YAL007C  chr1_1     ERP2               ER to Golgi transport
# 4  YAL008W  chr1_1    FUN14          biological_process unknown
#
#                   GO_function          GO_component deletion_phenotype  \
# 0  molecular_function unknown     membrane fraction             viable
# 1                         NaN                   NaN             viable
# 2   unfolded protein binding*            cytoplasm*             viable
# 3  molecular_function unknown  COPII-coated vesicle             viable
# 4  molecular_function unknown         mitochondrion             viable
#
#    result_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5  \
# 0                                           0.116074
# 1                                          -0.064984
# 2                                           0.096918
# 3                                           0.316698
# 4                                           0.406762
#
#    significant_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    rank_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5  ...  \
# 0                                               2175    ...
# 1                                               3170    ...
# 2                                               2277    ...
# 3                                               1033    ...
# 4                                                692    ...
#
#    rank_np:04_05_12_10:camptothecin:30:ug/ml::::hom_09_02:20  \
# 0                                                376
# 1                                                929
# 2                                               2984
# 3                                               1426
# 4                                               1161
#
#    result_np:04_07_16_08:camptothecin:30000:ug/ml::::hom_09_02:20  \
# 0                                          -0.008221
# 1                                          -0.448587
# 2                                           0.002291
# 3                                          -0.138989
# 4                                          -0.317520
#
#    significant_np:04_07_16_08:camptothecin:30000:ug/ml::::hom_09_02:20  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    rank_np:04_07_16_08:camptothecin:30000:ug/ml::::hom_09_02:20  \
# 0                                               2065
# 1                                               4338
# 2                                               1471
# 3                                               2785
# 4                                               3880
#
#    result_np:04_08_03_07:4nqo:0.0313:uM::::hom_09_02:5  \
# 0                                           0.256250
# 1                                           0.231566
# 2                                           1.097860
# 3                                           0.466131
# 4                                           0.400567
#
#    significant_np:04_08_03_07:4nqo:0.0313:uM::::hom_09_02:5  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    rank_np:04_08_03_07:4nqo:0.0313:uM::::hom_09_02:5  \
# 0                                               1242
# 1                                               1322
# 2                                                143
# 3                                                730
# 4                                                851
#
#    result_np:04_08_05_01:4nqo:0.0313:uM::::hom_09_02:5  \
# 0                                           0.786972
# 1                                           0.475449
# 2                                           0.669276
# 3                                           0.803323
# 4                                           0.778996
#
#    significant_np:04_08_05_01:4nqo:0.0313:uM::::hom_09_02:5  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    rank_np:04_08_05_01:4nqo:0.0313:uM::::hom_09_02:5
# 0                                                294
# 1                                                650
# 2                                                413
# 3                                                283
# 4                                                306
#
# [5 rows x 115 columns]

# %%
original_data['orf'] = original_data['ORF'].astype(str)

# %%
# Eliminate all white spaces & capitalize
original_data['orf'] = clean_orf(original_data['orf'])

# %%
# Translate to ORFs 
original_data['orf'] = translate_sc(original_data['orf'], to='orf')

# %%
# Make sure everything translated ok
t = looks_like_orf(original_data['orf'])
print(original_data.loc[~t,])
# Out:
# Empty DataFrame
# Columns: [ORF, Batch, Gene, GO_process, GO_function, GO_component, deletion_phenotype, result_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5, significant_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5, rank_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5, result_np:04_03_17_06:cisplatin:500:uM::::hom_09_02:5, significant_np:04_03_17_06:cisplatin:500:uM::::hom_09_02:5, rank_np:04_03_17_06:cisplatin:500:uM::::hom_09_02:5, result_np:03_04_04_03:cisplatin:500:uM::::hom_05_01:20, significant_np:03_04_04_03:cisplatin:500:uM::::hom_05_01:20, rank_np:03_04_04_03:cisplatin:500:uM::::hom_05_01:20, result_np:03_04_04_04:cisplatin:500:uM::::hom_05_01:20, significant_np:03_04_04_04:cisplatin:500:uM::::hom_05_01:20, rank_np:03_04_04_04:cisplatin:500:uM::::hom_05_01:20, result_np:04_03_09_01:carboplatin:15000:uM::::hom_09_02:5, significant_np:04_03_09_01:carboplatin:15000:uM::::hom_09_02:5, rank_np:04_03_09_01:carboplatin:15000:uM::::hom_09_02:5, result_np:04_03_30_02:carboplatin:15:mM::::hom_09_02:5, significant_np:04_03_30_02:carboplatin:15:mM::::hom_09_02:5, rank_np:04_03_30_02:carboplatin:15:mM::::hom_09_02:5, result_np:04_02_24_07:oxaliplatin:4000:uM::::hom_09_02:5, significant_np:04_02_24_07:oxaliplatin:4000:uM::::hom_09_02:5, rank_np:04_02_24_07:oxaliplatin:4000:uM::::hom_09_02:5, result_np:04_03_17_07:oxaliplatin:4000:uM::::hom_09_02:5, significant_np:04_03_17_07:oxaliplatin:4000:uM::::hom_09_02:5, rank_np:04_03_17_07:oxaliplatin:4000:uM::::hom_09_02:5, result_np:04_03_17_10:psoralen irradiated:0.5:uM::::hom_09_02:5, significant_np:04_03_17_10:psoralen irradiated:0.5:uM::::hom_09_02:5, rank_np:04_03_17_10:psoralen irradiated:0.5:uM::::hom_09_02:5, result_np:04_03_25_05:psoralen irradiated:0.5:uM::::hom_09_02:5, significant_np:04_03_25_05:psoralen irradiated:0.5:uM::::hom_09_02:5, rank_np:04_03_25_05:psoralen irradiated:0.5:uM::::hom_09_02:5, result_np:04_03_17_12:angelicin irradiated:62.5:uM::::hom_09_02:5, significant_np:04_03_17_12:angelicin irradiated:62.5:uM::::hom_09_02:5, rank_np:04_03_17_12:angelicin irradiated:62.5:uM::::hom_09_02:5, result_np:04_03_25_06:angelicin irradiated:62.5:uM::::hom_09_02:5, significant_np:04_03_25_06:angelicin irradiated:62.5:uM::::hom_09_02:5, rank_np:04_03_25_06:angelicin irradiated:62.5:uM::::hom_09_02:5, result_np:03_12_09_16:mechlorethamine:62.5:uM::::hom_09_02:5, significant_np:03_12_09_16:mechlorethamine:62.5:uM::::hom_09_02:5, rank_np:03_12_09_16:mechlorethamine:62.5:uM::::hom_09_02:5, result_np:03_12_19_01:mechlorethamine:62.5:uM::::hom_09_02:5, significant_np:03_12_19_01:mechlorethamine:62.5:uM::::hom_09_02:5, rank_np:03_12_19_01:mechlorethamine:62.5:uM::::hom_09_02:5, result_np:04_01_21_09:mechlorethamine:62.5:uM::::hom_09_02:5, significant_np:04_01_21_09:mechlorethamine:62.5:uM::::hom_09_02:5, rank_np:04_01_21_09:mechlorethamine:62.5:uM::::hom_09_02:5, result_np:02_12_18_13:mechlorethamine:62.5:uM::::hom_05_01:20, significant_np:02_12_18_13:mechlorethamine:62.5:uM::::hom_05_01:20, rank_np:02_12_18_13:mechlorethamine:62.5:uM::::hom_05_01:20, result_np:03_02_05_04:mechlorethamine:62.5:uM::::hom_05_01:20, significant_np:03_02_05_04:mechlorethamine:62.5:uM::::hom_05_01:20, rank_np:03_02_05_04:mechlorethamine:62.5:uM::::hom_05_01:20, result_np:03_02_05_05:mechlorethamine:62.5:uM::::hom_05_01:20, significant_np:03_02_05_05:mechlorethamine:62.5:uM::::hom_05_01:20, rank_np:03_02_05_05:mechlorethamine:62.5:uM::::hom_05_01:20, result_np:03_03_20_07:mechlorethamine:62.5:uM::::hom_05_01:20, significant_np:03_03_20_07:mechlorethamine:62.5:uM::::hom_05_01:20, rank_np:03_03_20_07:mechlorethamine:62.5:uM::::hom_05_01:20, result_np:03_03_20_08:mechlorethamine:62.5:uM::::hom_05_01:20, significant_np:03_03_20_08:mechlorethamine:62.5:uM::::hom_05_01:20, rank_np:03_03_20_08:mechlorethamine:62.5:uM::::hom_05_01:20, result_np:04_03_09_06:2-dmaec:240000:uM::::hom_09_02:5, significant_np:04_03_09_06:2-dmaec:240000:uM::::hom_09_02:5, rank_np:04_03_09_06:2-dmaec:240000:uM::::hom_09_02:5, result_np:04_03_17_15:2-dmae ...
# Index: []
#
# [0 rows x 116 columns]

# %%
data_cols = [c for c in original_data.columns.values if c.startswith('result_np')]
data_cols
# Out:
# ['result_np:04_02_24_05:cisplatin:500:uM::::hom_09_02:5',
#  'result_np:04_03_17_06:cisplatin:500:uM::::hom_09_02:5',
#  'result_np:03_04_04_03:cisplatin:500:uM::::hom_05_01:20',
#  'result_np:03_04_04_04:cisplatin:500:uM::::hom_05_01:20',
#  'result_np:04_03_09_01:carboplatin:15000:uM::::hom_09_02:5',
#  'result_np:04_03_30_02:carboplatin:15:mM::::hom_09_02:5',
#  'result_np:04_02_24_07:oxaliplatin:4000:uM::::hom_09_02:5',
#  'result_np:04_03_17_07:oxaliplatin:4000:uM::::hom_09_02:5',
#  'result_np:04_03_17_10:psoralen irradiated:0.5:uM::::hom_09_02:5',
#  'result_np:04_03_25_05:psoralen irradiated:0.5:uM::::hom_09_02:5',
#  'result_np:04_03_17_12:angelicin irradiated:62.5:uM::::hom_09_02:5',
#  'result_np:04_03_25_06:angelicin irradiated:62.5:uM::::hom_09_02:5',
#  'result_np:03_12_09_16:mechlorethamine:62.5:uM::::hom_09_02:5',
#  'result_np:03_12_19_01:mechlorethamine:62.5:uM::::hom_09_02:5',
#  'result_np:04_01_21_09:mechlorethamine:62.5:uM::::hom_09_02:5',
#  'result_np:02_12_18_13:mechlorethamine:62.5:uM::::hom_05_01:20',
#  'result_np:03_02_05_04:mechlorethamine:62.5:uM::::hom_05_01:20',
#  'result_np:03_02_05_05:mechlorethamine:62.5:uM::::hom_05_01:20',
#  'result_np:03_03_20_07:mechlorethamine:62.5:uM::::hom_05_01:20',
#  'result_np:03_03_20_08:mechlorethamine:62.5:uM::::hom_05_01:20',
#  'result_np:04_03_09_06:2-dmaec:240000:uM::::hom_09_02:5',
#  'result_np:04_03_17_15:2-dmaec:240000:uM::::hom_09_02:5',
#  'result_np:04_02_24_02:mitomycin c:1000:uM::::hom_09_02:5',
#  'result_np:04_03_30_03:mitomycin c:1:mM::::hom_09_02:5',
#  'result_np:04_03_17_16:streptozotocin:2000:uM::::hom_09_02:5',
#  'result_np:04_03_25_07:streptozotocin:2:mM::::hom_09_02:5',
#  'result_np:03_10_08_13:streptozotocin (sigma):2000:uM::::hom_09_02:20',
#  'result_np:04_07_16_09:streptozotocin:2:mM::::hom_09_02:20',
#  'result_np:04_02_24_03:mms:0.002:%::::hom_09_02:5',
#  'result_np:04_03_25_04:mms:0.002:%::::hom_09_02:5',
#  'result_np:04_03_25_01:camptothecin:30:ug/ml::::hom_09_02:5',
#  'result_np:04_03_30_01:camptothecin:30:ug/ml::::hom_09_02:5',
#  'result_np:04_05_12_10:camptothecin:30:ug/ml::::hom_09_02:20',
#  'result_np:04_07_16_08:camptothecin:30000:ug/ml::::hom_09_02:20',
#  'result_np:04_08_03_07:4nqo:0.0313:uM::::hom_09_02:5',
#  'result_np:04_08_05_01:4nqo:0.0313:uM::::hom_09_02:5']

# %%
original_data.set_index('orf', inplace=True)

# %%
original_data = -original_data[data_cols].apply(pd.to_numeric, axis=1, errors='coerce')

# %%
original_data = original_data.groupby(original_data.index).mean()

# %%
original_data.shape
# Out:
# (4717, 36)

# %% [markdown]
# # Load dataset_ids

# %%
dt = pd.read_csv('extras/screen_datasetids.txt', sep='\t', header=None)

# %%
dt.head()
# Out:
#                                                    0     1
# 0  result_np:04_02_24_05:cisplatin:500:uM::::hom_...   494
# 1  result_np:04_03_17_06:cisplatin:500:uM::::hom_...   494
# 2  result_np:03_04_04_03:cisplatin:500:uM::::hom_...  4964
# 3  result_np:03_04_04_04:cisplatin:500:uM::::hom_...  4964
# 4  result_np:04_03_09_01:carboplatin:15000:uM::::...  4965

# %%
dt.set_index(0, inplace=True)
dt = dt.reindex(index=original_data.columns.values)

# %%
dataset_ids = dt[1].values

# %%
original_data.columns = dataset_ids

# %%
original_data = original_data.T
original_data = original_data.groupby(original_data.index).mean()
original_data = original_data.T

# %% [markdown]
# # Prepare the final dataset

# %%
data = original_data.copy()

# %%
dataset_ids = original_data.columns.values
datasets = datasets.reindex(index=dataset_ids)

# %%
lst = [datasets.index.values, ['value']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data.columns = idx

# %%
data.head()
# Out:
# dataset_id      494       4964      4965      4966      4968      4969  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W    -0.338666  0.694700 -0.824313 -1.200845 -0.747015 -0.496401
# YAL004W     0.032969  0.430370 -0.282600 -0.110506 -0.195279 -0.290994
# YAL005C    -0.046967  0.510715 -0.210452 -0.163509  0.214631 -0.285610
# YAL007C    -0.219635  0.473252 -0.085367 -0.216700 -0.133014 -0.315444
# YAL008W    -0.360553  0.232798 -0.409533 -0.268421 -0.556293 -0.306052
#
# dataset_id      4970      4971      4972      4973      4974      4975  \
# data_type      value     value     value     value     value     value
# orf
# YAL002W    -0.359019  0.736572 -0.969445 -0.488517 -0.028722 -0.201861
# YAL004W    -0.104367  0.215729 -0.209674 -0.333938  0.238522 -0.359463
# YAL005C    -0.102062  0.504963 -0.374931  0.245477  0.190685 -0.293942
# YAL007C    -0.107625  0.606121 -0.376927 -0.088237  0.449832 -0.465453
# YAL008W     0.035683 -0.109149 -0.290878 -0.608148  0.466965 -0.741321
#
# dataset_id      4976      4977      4978      4979
# data_type      value     value     value     value
# orf
# YAL002W    -0.512620 -0.195746  0.090528 -0.521611
# YAL004W    -0.243652  0.150169  0.141267 -0.353507
# YAL005C    -0.055244  0.044331  0.381204 -0.883568
# YAL007C    -0.162218  0.043169  0.120192 -0.634727
# YAL008W    -0.435253  0.109985 -0.442898 -0.589781

# %% [markdown]
# ## Subset to the genes currently in SGD

# %%
genes = pd.read_csv(path_to_genes, sep='\t', index_col='id')
genes = genes.reset_index().set_index('systematic_name')
gene_ids = genes.reindex(index=data.index.values)['id'].values
num_missing = np.sum(np.isnan(gene_ids))
print('ORFs missing from SGD: %d' % num_missing)
# Out:
# ORFs missing from SGD: 22

# %%
data['gene_id'] = gene_ids
data = data.loc[data['gene_id'].notnull()]
data['gene_id'] = data['gene_id'].astype(int)
data = data.reset_index().set_index(['gene_id','orf'])

data.head()
# Out:
# dataset_id           494       4964      4965      4966      4968      4969  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W -0.338666  0.694700 -0.824313 -1.200845 -0.747015 -0.496401
# 1863    YAL004W  0.032969  0.430370 -0.282600 -0.110506 -0.195279 -0.290994
# 4       YAL005C -0.046967  0.510715 -0.210452 -0.163509  0.214631 -0.285610
# 5       YAL007C -0.219635  0.473252 -0.085367 -0.216700 -0.133014 -0.315444
# 6       YAL008W -0.360553  0.232798 -0.409533 -0.268421 -0.556293 -0.306052
#
# dataset_id           4970      4971      4972      4973      4974      4975  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W -0.359019  0.736572 -0.969445 -0.488517 -0.028722 -0.201861
# 1863    YAL004W -0.104367  0.215729 -0.209674 -0.333938  0.238522 -0.359463
# 4       YAL005C -0.102062  0.504963 -0.374931  0.245477  0.190685 -0.293942
# 5       YAL007C -0.107625  0.606121 -0.376927 -0.088237  0.449832 -0.465453
# 6       YAL008W  0.035683 -0.109149 -0.290878 -0.608148  0.466965 -0.741321
#
# dataset_id           4976      4977      4978      4979
# data_type           value     value     value     value
# gene_id orf
# 2       YAL002W -0.512620 -0.195746  0.090528 -0.521611
# 1863    YAL004W -0.243652  0.150169  0.141267 -0.353507
# 4       YAL005C -0.055244  0.044331  0.381204 -0.883568
# 5       YAL007C -0.162218  0.043169  0.120192 -0.634727
# 6       YAL008W -0.435253  0.109985 -0.442898 -0.589781

# %% [markdown]
# # Normalize

# %%
data_norm = normalize_phenotypic_scores(data, has_tested=True)

# %%
# Assign proper column names
lst = [datasets.index.values, ['valuez']*datasets.shape[0]]
tuples = list(zip(*lst))
idx = pd.MultiIndex.from_tuples(tuples, names=['dataset_id','data_type'])
data_norm.columns = idx

# %%
data_norm[data.isnull()] = np.nan
data_all = data.join(data_norm)

data_all.head()
# Out:
# dataset_id           494       4964      4965      4966      4968      4969  \
# data_type           value     value     value     value     value     value
# gene_id orf
# 2       YAL002W -0.338666  0.694700 -0.824313 -1.200845 -0.747015 -0.496401
# 1863    YAL004W  0.032969  0.430370 -0.282600 -0.110506 -0.195279 -0.290994
# 4       YAL005C -0.046967  0.510715 -0.210452 -0.163509  0.214631 -0.285610
# 5       YAL007C -0.219635  0.473252 -0.085367 -0.216700 -0.133014 -0.315444
# 6       YAL008W -0.360553  0.232798 -0.409533 -0.268421 -0.556293 -0.306052
#
# dataset_id           4970      4971      4972      4973  ...      4970  \
# data_type           value     value     value     value  ...    valuez
# gene_id orf                                              ...
# 2       YAL002W -0.359019  0.736572 -0.969445 -0.488517  ... -0.704055
# 1863    YAL004W -0.104367  0.215729 -0.209674 -0.333938  ... -0.197980
# 4       YAL005C -0.102062  0.504963 -0.374931  0.245477  ... -0.193400
# 5       YAL007C -0.107625  0.606121 -0.376927 -0.088237  ... -0.204455
# 6       YAL008W  0.035683 -0.109149 -0.290878 -0.608148  ...  0.080343
#
# dataset_id           4971      4972      4973      4974      4975      4976  \
# data_type          valuez    valuez    valuez    valuez    valuez    valuez
# gene_id orf
# 2       YAL002W  1.521954 -1.090261 -1.437050 -0.223454  0.049393 -1.065767
# 1863    YAL004W  0.379559  0.042460 -1.017946  0.441389 -0.284242 -0.362688
# 4       YAL005C  1.013951 -0.203917  0.552999  0.322380 -0.145538  0.129806
# 5       YAL007C  1.235827 -0.206893 -0.351786  0.967079 -0.508616 -0.149823
# 6       YAL008W -0.333013 -0.078605 -1.761401  1.009702 -1.092615 -0.863530
#
# dataset_id           4977      4978      4979
# data_type          valuez    valuez    valuez
# gene_id orf
# 2       YAL002W -0.609945 -0.006000 -0.898849
# 1863    YAL004W  0.359577  0.097012 -0.601291
# 4       YAL005C  0.062936  0.584149 -1.539545
# 5       YAL007C  0.059681  0.054226 -1.099075
# 6       YAL008W  0.246950 -1.088998 -1.019517
#
# [5 rows x 32 columns]

# %% [markdown]
# # Print out

# %%
for f in ['value','valuez']:
    df = data_all.xs(f, level='data_type', axis=1).copy()
    df.columns = datasets['name'].values
    df = df.droplevel('gene_id', axis=0)
    df.to_csv(paper_name + '_' + f + '.txt', sep='\t')

# %% [markdown]
# # Save to DB

# %%
from IO.save_data_to_db3 import *

# %%
save_data_to_db(data_all, paper_pmid)
# Out:
# Deleting all datasets for PMID 16121259...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Inserting the new data...
# 100%|██████████| 16/16 [01:57<00:00,  7.37s/it]
# Updating the data_modified_on field...
